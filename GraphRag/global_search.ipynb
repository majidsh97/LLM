# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.indexer_adapters import read_indexer_entities, read_indexer_reports
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch

# %%
BASE_URL = "http://localhost:8080/"
MODEL_NAME = "gpt-4o"

llm = ChatOpenAI(
    api_key="api_key",
    model=MODEL_NAME,
    api_base=BASE_URL,
    api_type=OpenaiApiType.OpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

# %%
# parquet files generated from indexing pipeline
INPUT_DIR = "/home/cip/ce/ix05ogym/Majid/LLM/GraphRag/elec_graph/output"
COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"

# community level in the Leiden community hierarchy from which we will load the community reports
# higher value means we use reports from more fine-grained communities (at the cost of higher computation cost)
COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
print(f"Total report count: {len(report_df)}")
print(
    f"Report count after filtering by community level {COMMUNITY_LEVEL}: {len(reports)}"
)
report_df.head()
# Out:
# Total report count: 73
# Report count after filtering by community level 2: 57
#   community                                       full_content  level  rank  \
# 0        58  # Soldering and Electronics Assembly\n\nThis c...      2   7.0
# 1        59  # Flux and Solderability\n\nThis community rev...      2   3.0
# 2        60  # Assembly and its Associated Faults\n\nThis c...      2   7.0
# 3        61  # Component Assembly and Manufacturing\n\nThis...      2   7.0
# 4        62  # Electrical Connections and Circuits\n\nThis ...      2   3.0
#
#                                   title  \
# 0    Soldering and Electronics Assembly
# 1                Flux and Solderability
# 2    Assembly and its Associated Faults
# 3  Component Assembly and Manufacturing
# 4   Electrical Connections and Circuits
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The impact severity rating is low due to the l...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is high due to the ...
# 4  The impact severity rating is low due to the t...
#
#                                              summary  \
# 0  This community revolves around the process of ...
# 1  This community revolves around the concept of ...
# 2  This community revolves around the concept of ...
# 3  This community focuses on the assembly and man...
# 4  This community revolves around the concept of ...
#
#                                             findings  \
# 0  [{'explanation': 'Soldering is the central ent...
# 1  [{'explanation': 'Flux is a key entity in this...
# 2  [{'explanation': 'Assembly is a fundamental pr...
# 3  [{'explanation': 'Components are the fundament...
# 4  [{'explanation': 'Soldering is a crucial techn...
#
#                                    full_content_json  \
# 0  {\n    "title": "Soldering and Electronics Ass...
# 1  {\n    "title": "Flux and Solderability",\n   ...
# 2  {\n    "title": "Assembly and its Associated F...
# 3  {\n    "title": "Component Assembly and Manufa...
# 4  {\n    "title": "Electrical Connections and Ci...
#
#                                      id
# 0  b35de978-ca01-44d7-a012-7b6526ae3412
# 1  287df284-3c47-4e78-8024-7bfed14af4ee
# 2  797c3220-46e5-4c6f-9a3a-83da48391eb3
# 3  65dff29b-096d-4a55-aaef-66de20e2de64
# 4  d294c6d5-ba91-42de-a01e-1aa6c4b21978

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    entities=entities,  # default to None if you don't want to use community weights for ranking
    token_encoder=token_encoder,
)

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 2000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000-1500)
    "temperature": 0.0,
}

# %%
search_engine = GlobalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
result = await search_engine.asearch(
    "describe soldering metrics"
)

print(result.response)
# Out:
# Soldering is a crucial process in electronics manufacturing, directly impacting the reliability and performance of electronic circuits and assemblies. [Data: Reports (10, 71, 58, 38)] A high-quality soldered joint ensures a strong and reliable connection, meeting its intended purpose. [Data: Reports (10, 71, 58, 38)] This is achieved by ensuring the soldered joints are properly formed, free from defects, and meet the required specifications. [Data: Reports (10, 71, 58, 38)]
#
# **Solderability** is a key metric in soldering, referring to the ability of a metal surface to be wetted by solder. [Data: Reports (71)] Several factors can affect solderability, including the cleanliness of the surface, the type of metal, the presence of oxides and contaminants, and the soldering process itself. [Data: Reports (71)] Oxidation, in particular, can hinder solderability by forming a layer of oxide on the surface of metals, creating a barrier between the solder and the metal surface. [Data: Reports (71)] Flux plays a crucial role in improving solderability by removing oxides and contaminants from the surface of metals, allowing the solder to flow properly and create a strong bond. [Data: Reports (71)]
#
# **Solder joint quality** is another important metric, encompassing various aspects such as the appearance, shape, and integrity of the joint. [Data: Reports (10, 38)] Defects in soldered joints can lead to poor quality products. [Data: Reports (10)] Defects increase cost. [Data: Reports (10)]  Inspection can identify defects. [Data: Reports (10)] Process control can reduce defects. [Data: Reports (10)]
#
# **Visual inspection** is often used to assess the quality of solder joints. [Data: Reports (38)] This involves looking for signs of defects such as poor wetting, voids, or cracks in the joint. [Data: Reports (38)] Brightness and smoothness are often used as visual indicators of the quality of a solder joint. [Data: Reports (38)] However, visual checks are often subjective and may not be reliable for detecting all defects. [Data: Reports (38)]
#
# **Process control** is essential for ensuring consistent soldering quality. [Data: Reports (10)] The soldering process is a key factor in determining the quality of the soldered joint. [Data: Reports (10)]  Consistency in the process leads to higher quality. [Data: Reports (10)] Machine soldering can improve quality. [Data: Reports (10)] Process control can improve quality. [Data: Reports (10)] Proper training leads to higher quality. [Data: Reports (10)]
#
# **Cost** is also a significant factor in soldering. [Data: Reports (10)] Higher quality often leads to higher cost. [Data: Reports (10)] Machine soldering can reduce cost. [Data: Reports (10)] Touch-up increases cost. [Data: Reports (10)] Inspection increases cost. [Data: Reports (10)]
#
# **Consistency** is another important metric in soldering. [Data: Reports (10)] Machine soldering can improve consistency. [Data: Reports (10)] Process control can improve consistency. [Data: Reports (10)]
#
# **Capillary action** is a phenomenon that occurs when a liquid flows in a narrow space, such as between two surfaces. [Data: Reports (38)] In the context of soldering, capillary action is used to draw solder into the space between a component lead and a copper track on a printed circuit board. [Data: Reports (38)] The solder is drawn into the space by the forces of adhesion between the solder and the copper and the forces of cohesion between the solder molecules. [Data: Reports (38)]
#
# In summary, soldering metrics encompass various aspects, including solderability, solder joint quality, process control, cost, and consistency. [Data: Reports (10, 71, 58, 38)] These metrics are crucial for ensuring the reliability and performance of electronic devices. [Data: Reports (10, 71, 58, 38)]

# %%
# inspect the data used to build the context for the LLM responses
result.context_data["reports"]
# Out:
#     id                                              title  occurrence weight  \
# 0   28                Printed Circuit Board Manufacturing           0.894737
# 1   10  Soldering Quality and Cost in Electronics Manu...           0.526316
# 2   68         SC Soldering and Surface Mounting Assembly           0.368421
# 3   48     Copper, Tin, and Board in Electronics Assembly           0.263158
# 4   49     Cleaning and Soldering in Electronics Assembly           0.263158
# 5   53            SI-GC-CU-13 Laminate and its Properties           0.263158
# 6   20                  Hand Soldering and Soldering Iron           0.263158
# 7   15     Electronics Assemblies and Soldering Processes           0.210526
# 8   65    Soldering Process and Electronics Manufacturing           0.210526
# 9   63            Dip, Drag, and Wave Soldering Processes           0.210526
# 10  42   Surface Mounted Components and Portable Products           0.157895
# 11  17                  Solder Paste and its Applications           0.157895
# 12  44                      Property, Attribute, and Test           0.157895
# 13  36   Assembly Technology and Surface Mount Technology           0.105263
# 14   5         Standards, Organizations, and Requirements           0.105263
# 15  16                        Soldering and Contamination           0.105263
# 16  21                       ITRI and Lead-Free Soldering           0.105263
# 17  57                    Material, Substance, and Fibers           0.105263
# 18  56                            Application and Purpose           0.105263
# 19  66                   Hazardous Materials in Soldering           0.052632
# 20  37       Electronic Assembly and Component Technology           0.052632
# 21  40  Small Form-Factor Components and Electronic Sy...           0.052632
# 22  72             Printed Circuit Boards and Lead Counts           0.052632
# 23  32                    Alan Keyte, Nokia, and Motorola           0.052632
# 24  31                                     Bolts and Nuts           0.052632
# 25  67                       Soldering and its Components           0.894737
# 26  61               Component Assembly and Manufacturing           0.578947
# 27  71  Solderability and its Impact on Electronics As...           0.421053
# 28   9             Metal and Solder Joints in Electronics           0.368421
# 29  43             Lead and its Impact on the Environment           0.368421
# 30  60                 Assembly and its Associated Faults           0.315789
# 31  39  Component Lead, Copper Track, and Printed Circ...           0.263158
# 32  14             Soldering and its Associated Phenomena           0.210526
# 33  23                  Soldering Process and its Factors           0.210526
# 34  62                Electrical Connections and Circuits           0.210526
# 35  46                           Short Circuit and Damage           0.157895
# 36  18                      Soldering and Further Reading           0.157895
# 37  50  Electronics Industry: Cookson Electronics and ...           0.105263
# 38  69        BS 4584 and Printed Circuit Board Laminates           0.105263
# 39  64               Wave Soldering and Related Processes           0.105263
# 40  70                           Letter Codes and BS 4584           0.105263
# 41  22                   Soldering Problems and Solutions           0.105263
# 42  30                               SYSTEM and STRUCTURE           0.105263
# 43  25  186 SC Soldering Processes and Related Technol...           0.105263
# 44  29                                   OBJECT and THING           0.105263
# 45   8        Printed Wiring Boards and Related Processes           0.052632
# 46  41               Packaging Strategy and Stock Holding           0.052632
# 47  51                David Crimp and Europe Alpha Metals           0.052632
# 48  35  Reflow Processes and Solid Solder in SC Soldering           0.052632
# 49  24                             REFERENCES and SOURCES           0.052632
# 50  58                 Soldering and Electronics Assembly           1.000000
# 51  59                             Flux and Solderability           0.421053
# 52  52  Electronics Industry: Engineers, Suppliers, an...           0.210526
# 53  38             Solder Joint and its Related Processes           0.210526
# 54  55             Layers, Laminates, and Glass Filaments           0.157895
# 55  54                      Action, Event, and Occurrence           0.105263
# 56  19                    Glossary and Terms in Soldering           0.052632
#
#                                               content  rank
# 0   # Printed Circuit Board Manufacturing\n\nThe c...   7.0
# 1   # Soldering Quality and Cost in Electronics Ma...   7.0
# 2   # SC Soldering and Surface Mounting Assembly\n...   3.0
# 3   # Copper, Tin, and Board in Electronics Assemb...   7.0
# 4   # Cleaning and Soldering in Electronics Assemb...   7.0
# 5   # SI-GC-CU-13 Laminate and its Properties\n\nT...   3.0
# 6   # Hand Soldering and Soldering Iron\n\nThis co...   2.0
# 7   # Electronics Assemblies and Soldering Process...   7.0
# 8   # Soldering Process and Electronics Manufactur...   6.0
# 9   # Dip, Drag, and Wave Soldering Processes\n\nT...   3.0
# 10  # Surface Mounted Components and Portable Prod...   7.0
# 11  # Solder Paste and its Applications\n\nThis co...   3.0
# 12  # Property, Attribute, and Test\n\nThis commun...   3.0
# 13  # Assembly Technology and Surface Mount Techno...   7.0
# 14  # Standards, Organizations, and Requirements\n...   4.0
# 15  # Soldering and Contamination\n\nThis communit...   3.0
# 16  # ITRI and Lead-Free Soldering\n\nThis communi...   3.0
# 17  # Material, Substance, and Fibers\n\nThis comm...   2.0
# 18  # Application and Purpose\n\nThis community co...   1.0
# 19  # Hazardous Materials in Soldering\n\nThis com...   7.0
# 20  # Electronic Assembly and Component Technology...   7.0
# 21  # Small Form-Factor Components and Electronic ...   6.0
# 22  # Printed Circuit Boards and Lead Counts\n\nTh...   3.0
# 23  # Alan Keyte, Nokia, and Motorola\n\nThis comm...   2.0
# 24  # Bolts and Nuts\n\nThis community consists of...   1.0
# 25  # Soldering and its Components\n\nThis communi...   7.0
# 26  # Component Assembly and Manufacturing\n\nThis...   7.0
# 27  # Solderability and its Impact on Electronics ...   7.0
# 28  # Metal and Solder Joints in Electronics\n\nTh...   7.0
# 29  # Lead and its Impact on the Environment\n\nTh...   7.0
# 30  # Assembly and its Associated Faults\n\nThis c...   7.0
# 31  # Component Lead, Copper Track, and Printed Ci...   7.0
# 32  # Soldering and its Associated Phenomena\n\nTh...   7.0
# 33  # Soldering Process and its Factors\n\nThis co...   3.0
# 34  # Electrical Connections and Circuits\n\nThis ...   3.0
# 35  # Short Circuit and Damage\n\nThis community r...   7.0
# 36  # Soldering and Further Reading\n\nThis commun...   2.0
# 37  # Electronics Industry: Cookson Electronics an...   7.0
# 38  # BS 4584 and Printed Circuit Board Laminates\...   3.0
# 39  # Wave Soldering and Related Processes\n\nThis...   3.0
# 40  # Letter Codes and BS 4584\n\nThis community r...   2.0
# 41  # Soldering Problems and Solutions\n\nThis com...   2.0
# 42  # SYSTEM and STRUCTURE\n\nThe community consis...   2.0
# 43  # 186 SC Soldering Processes and Related Techn...   2.0
# 44  # OBJECT and THING\n\nThis community consists ...   1.0
# 45  # Printed Wiring Boards and Related Processes\...   7.0
# 46  # Packaging Strategy and Stock Holding\n\nThis...   3.0
# 47  # David Crimp and Europe Alpha Metals\n\nThis ...   3.0
# 48  # Reflow Processes and Solid Solder in SC Sold...   2.0
# 49  # REFERENCES and SOURCES\n\nThis community is ...   1.0
# 50  # Soldering and Electronics Assembly\n\nThis c...   7.0
# 51  # Flux and Solderability\n\nThis community rev...   3.0
# 52  # Electronics Industry: Engineers, Suppliers, ...   7.0
# 53  # Solder Joint and its Related Processes\n\nTh...   7.0
# 54  # Layers, Laminates, and Glass Filaments\n\nTh...   3.0
# 55  # Action, Event, and Occurrence\n\nThis commun...   2.0
# 56  # Glossary and Terms in Soldering\n\nThis comm...   2.0

# %%
# inspect number of LLM calls and tokens
print(f"LLM calls: {result.llm_calls}. LLM tokens: {result.prompt_tokens}")
# Out:
# LLM calls: 3. LLM tokens: 29212
