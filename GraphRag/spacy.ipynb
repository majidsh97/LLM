# %%
#--visual
#https://github.com/emmo-repo/EMMOntoPy/tree/master/tools
#ontograph
#ontoconvert
#ontodoc
#----main
#https://neo4j.com/labs/apoc/5/nlp/build-knowledge-graph-nlp-ontologies/#custom-onotology
#https://neo4j.com/labs/apoc/4.1/nlp/gcp/#nlp-gcp-entities
#---

# %%
STACK_TTL = "/home/cip/ce/ix05ogym/Majid/LLM/GraphRag/stack.ttl"
GPO_TTL = 'https://github.com/General-Process-Ontology/ontology/blob/master/GPO.ttl'

# %%
import spacy

text_en = "Victor Hugo and Honoré de Balzac are French writers who lived in Paris."

nlp_model_en = spacy.load("en_core_web_sm")

nlp_model_en.add_pipe("entityfishing")

doc_en = nlp_model_en(text_en)

for ent in doc_en.ents:
        print((ent.text, ent.label_, ent._.kb_qid, ent._.url_wikidata, ent._.nerd_score))
# Out:
# ('Victor Hugo', 'PERSON', None, None, None)
# ('Honoré de Balzac', 'PERSON', None, None, None)
# ('French', 'NORP', None, None, None)
# ('Paris', 'GPE', None, None, None)

# %%
from rdflib import Graph
import pygraphviz as pgv


g = Graph()

g.parse("/home/cip/ce/ix05ogym/Majid/LLM/GraphRag/stack.ttl", format="turtle")

A = pgv.AGraph(directed=True)

for s, p, o in g:
    print(str(p))
    #A.add_edge(s, o, label=p.split('#')[-1])

# Save and view the graph
#A.layout(prog="dot")  # Use the dot layout engine
#A.draw("knowledge_graph.png")
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#comment
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2000/01/rdf-schema#subClassOf
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type

# %%
from owlready2 import get_ontology

# Load the ontology using owlready2
STACK_OWL = "/home/cip/ce/ix05ogym/Majid/LLM/stack.owl"
GPO_OWL = "/home/cip/ce/ix05ogym/Majid/LLM/GPO.owl"

ontology = get_ontology(GPO_OWL).load()

# Access classes and properties
print("Classes:")
for cls in ontology.classes():
    print(cls.label,cls.is_a,cls.iri,list(cls.subclasses()))

print("\nObject Properties:")
for prop in ontology.object_properties():
    print(prop)

#list(ontology.classes())
# Out:
# Classes:
# [] [owl.Thing] https://w3id.org/emmo#EMMO_43e9a05d_98af_41b4_92f6_00f79a09bfce [GPO.GPO_01cd2578_8730_4ac9_a555_9112728ea939, GPO.GPO_70b20870_3beb_414a_b91f_2b6d234fda1a, GPO.GPO_ee8c37fd_9f2c_4047_b25d_4149894bd7c0, GPO.GPO_c4600586_ccc8_4d4b_b7a2_123d5aa2d77d, GPO.GPO_aa602472_ba16_4375_b8b3_868f84324ec7]
# [] [owl.Thing] https://w3id.org/emmo#EMMO_49804605_c0fe_4538_abda_f70ba1dc8a5d []
# [] [owl.Thing] https://w3id.org/emmo#EMMO_98ada9d8_f1c8_4f13_99b5_d890f5354152 []
# [] [emmo.EMMO_b803f122_4acb_4064_9d71_c1e5fd091fc9] https://gpo.ontology.link/GPO_995475ba_f196_4b19_a7c7_38d032c59270 []
# [] [GPO.GPO_2189e451_0054_4e25_8679_001ec2cdad7f] https://gpo.ontology.link/GPO_d7b2ecea_f055_4e3e_b5b9_020b8d81130d []
# [] [GPO.GPO_fb793a58_4083_42ad_a03c_27f594793b16] https://gpo.ontology.link/GPO_2189e451_0054_4e25_8679_001ec2cdad7f [GPO.GPO_d7b2ecea_f055_4e3e_b5b9_020b8d81130d, GPO.GPO_48094cc5_05e6_4f0b_b8c2_5561497f8a8e]
# [] [GPO.GPO_42631ff8_f9ce_408e_8446_99d5fd20dc6b] https://gpo.ontology.link/GPO_c5952e89_2710_4dfd_b87a_82d99cc6823b [GPO.GPO_99ef5665_e946_485d_b3ba_87e300564a95]
# [] [GPO.GPO_2be9b8b9_5ec8_46f3_89d6_3692c310553e] https://gpo.ontology.link/GPO_8678fb81_bb19_494c_ac8e_67a0ee65b0db [GPO.GPO_06512cb1_63cc_493a_84fd_44551b94d88b, GPO.GPO_927388fd_eb32_4c1f_9a58_ee41a6ed55a4]
# [] [GPO.GPO_c26bce9d_2372_455d_a822_ee50d068907c] https://gpo.ontology.link/GPO_a3523448_8f6e_4495_a591_5e1090652e16 []
# [] [GPO.GPO_e015afbe_407a_4dff_906a_bf0a15a93f6a] https://gpo.ontology.link/GPO_c26bce9d_2372_455d_a822_ee50d068907c [GPO.GPO_a3523448_8f6e_4495_a591_5e1090652e16]
# [] [GPO.GPO_3ac98139_d8cd_431e_89b6_a624942ff16e] https://gpo.ontology.link/GPO_e015afbe_407a_4dff_906a_bf0a15a93f6a [GPO.GPO_c26bce9d_2372_455d_a822_ee50d068907c, GPO.GPO_bc07577b_1e4b_4d60_aa8d_3cfd09e7c03a]
# [] [emmo.EMMO_5c68497d_2544_4cd4_897b_1ea783c9f6fe] https://gpo.ontology.link/GPO_cb3864f2_a9ce_4ee1_8838_2fd0bc95d4f1 []
# [] [GPO.GPO_bc07577b_1e4b_4d60_aa8d_3cfd09e7c03a] https://gpo.ontology.link/GPO_ffcc3d64_ad9b_4ce3_ba11_5bbf6c2c3111 []
# [] [GPO.GPO_e015afbe_407a_4dff_906a_bf0a15a93f6a] https://gpo.ontology.link/GPO_bc07577b_1e4b_4d60_aa8d_3cfd09e7c03a [GPO.GPO_ffcc3d64_ad9b_4ce3_ba11_5bbf6c2c3111, GPO.GPO_d89337ea_b7e4_4e81_a482_231aa25d1d39]
# [] [GPO.GPO_d84afb30_9eee_4c17_ab79_2de8895da4ad] https://gpo.ontology.link/GPO_5f02dbb0_2803_4aaa_9104_ba39f17a4c8d []
# [] [GPO.GPO_49fc895e_d6cf_4f12_bcc6_2ad94b75c212] https://gpo.ontology.link/GPO_d84afb30_9eee_4c17_ab79_2de8895da4ad [GPO.GPO_5f02dbb0_2803_4aaa_9104_ba39f17a4c8d, GPO.GPO_e6b5562d_14d5_4ad5_8079_7303b490e0c9, GPO.GPO_ce7db854_9e14_4339_9e71_a8d4ab8f6331, GPO.GPO_c531bf8b_27fe_43c5_8b12_f12f73545b8a]
# [] [GPO.GPO_2680e8c9_b5d0_4d50_9a33_52e4270669d8, GPO.GPO_f01f7920_d7e2_4d5a_8470_e4bf5c60565a] https://gpo.ontology.link/GPO_cfb09cee_db2b_4507_a9b0_4e9e23f65f54 []
# [] [GPO.GPO_f95f16fd_4ee0_4fa9_be7f_1e562747adfd] https://gpo.ontology.link/GPO_90552ed9_c06a_4612_8af8_8e3c6a394afa []
# [] [GPO.GPO_2be9b8b9_5ec8_46f3_89d6_3692c310553e] https://gpo.ontology.link/GPO_f95f16fd_4ee0_4fa9_be7f_1e562747adfd [GPO.GPO_90552ed9_c06a_4612_8af8_8e3c6a394afa, GPO.GPO_18daa97a_afc7_4227_b197_38cd2c694e05]
# [] [GPO.GPO_d84afb30_9eee_4c17_ab79_2de8895da4ad] https://gpo.ontology.link/GPO_e6b5562d_14d5_4ad5_8079_7303b490e0c9 []
# [] [GPO.GPO_2be9b8b9_5ec8_46f3_89d6_3692c310553e] https://gpo.ontology.link/GPO_ab6f9ec2_2d58_4c67_b40b_1f454148ec35 [GPO.GPO_39cf2373_f414_4295_92b8_7d60a91d7803]
# [] [emmo.EMMO_43e9a05d_98af_41b4_92f6_00f79a09bfce, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(GPO.GPO_a7003b69_ce78_48fe_a717_e04e1266c6cd), GPO.GPO_8c869b47_a258_43b9_9c75_4285a80a1dfb.some(GPO.GPO_a7003b69_ce78_48fe_a717_e04e1266c6cd), emmo.EMMO_ae2d1a96_bfa1_409a_a7d2_03d69e8a125a.some(GPO.GPO_6e556808_d24d_46f5_86eb_fdbbdc6e6ef1 | 'https://w3id.org/emmo#EMMO_0527413c_b286_4e9c_b2d0_03fb2a038dee')] https://gpo.ontology.link/GPO_ee8c37fd_9f2c_4047_b25d_4149894bd7c0 [GPO.GPO_849a339d_834e_40c0_b19c_168bccbeacfb]
# [] [GPO.GPO_a414dc9c_54bf_4263_9748_5ccbf52f262b] https://gpo.ontology.link/GPO_f716e88d_310c_492f_b6b1_0f358677b65e []
# [] [GPO.GPO_c4600586_ccc8_4d4b_b7a2_123d5aa2d77d] https://gpo.ontology.link/GPO_04b6cbaf_a63a_4130_974a_8cc9c2a612f1 []
# [] [emmo.EMMO_43e9a05d_98af_41b4_92f6_00f79a09bfce] https://gpo.ontology.link/GPO_c4600586_ccc8_4d4b_b7a2_123d5aa2d77d [GPO.GPO_04b6cbaf_a63a_4130_974a_8cc9c2a612f1, GPO.GPO_890abbc3_d75b_4f3f_a5b7_e1b0e898655b, GPO.GPO_bfaebe5c_1b0a_49d4_bf14_94e8d0546197]
# [] [GPO.GPO_6dab7b9a_48f2_4ab2_b031_214d5ceac2d0, emmo.EMMO_6703954e_34c4_4a15_a9e7_f313760ae1a8.some(GPO.GPO_fdf81376_fd5d_4f7a_ab0e_f22cd0d35bd2)] https://gpo.ontology.link/GPO_ba0bee97_1f2d_4201_b6dd_4868c8963780 []
# [] [GPO.GPO_fb793a58_4083_42ad_a03c_27f594793b16] https://gpo.ontology.link/GPO_c578a5f4_43d3_40a7_ad60_ceccc0697172 []
# [] [GPO.GPO_2189e451_0054_4e25_8679_001ec2cdad7f] https://gpo.ontology.link/GPO_48094cc5_05e6_4f0b_b8c2_5561497f8a8e [GPO.GPO_285d777d_6e73_444f_9a10_03983157b457]
# [] [GPO.GPO_a414dc9c_54bf_4263_9748_5ccbf52f262b] https://gpo.ontology.link/GPO_c879a010_1232_4d80_99f4_c53b7cbc6f4c []
# [] [GPO.GPO_0af58599_9d3d_480b_b28c_85bba198dc96, Inverse(emmo.EMMO_17e27c22_37e1_468c_9dd7_95e137f73e7f).some(GPO.GPO_087bb572_444a_4928_8e97_6d9fbf81e355)] https://gpo.ontology.link/GPO_983507d5_1d17_4846_9142_2c8baecf0b01 []
# [] [GPO.GPO_f116ab16_8764_4fee_bd14_52990ef3bd40] https://gpo.ontology.link/GPO_3bdc9b56_36b4_4a1b_bb80_3ce428997606 [GPO.GPO_a07cde42_e539_4442_a765_522eecea9ad8]
# [] [GPO.GPO_087bb572_444a_4928_8e97_6d9fbf81e355] https://gpo.ontology.link/GPO_2fec7b20_a62c_4a34_b558_de0c20e32b2b [GPO.GPO_9d7a60a1_72ee_4a92_9720_7f99971861b1]
# [] [owl.Thing] https://w3id.org/emmo#EMMO_31ec09ba_1713_42cb_83c7_b38bf6f9ced2 []
# [] [emmo.EMMO_1e877c70_3b01_45a8_a8f6_8ce4f6a24660] https://gpo.ontology.link/GPO_346074e2_96ff_4124_8ee9_2015c99a0b47 []
# [] [GPO.GPO_ce7db854_9e14_4339_9e71_a8d4ab8f6331] https://gpo.ontology.link/GPO_eec11194_1552_47db_a410_997d651c92aa []
# [] [GPO.GPO_d84afb30_9eee_4c17_ab79_2de8895da4ad] https://gpo.ontology.link/GPO_ce7db854_9e14_4339_9e71_a8d4ab8f6331 [GPO.GPO_eec11194_1552_47db_a410_997d651c92aa, GPO.GPO_f846eaba_e75a_49df_b71a_5f769e6a7e7e, GPO.GPO_f48e1432_3ddd_4077_824f_fc664c72f7cf, GPO.GPO_6729f82e_56bc_4fae_a69d_ad4655f245e0]
# [] [GPO.GPO_14953156_bec6_4935_a6c5_36920348d903] https://gpo.ontology.link/GPO_939ec66f_883f_41eb_aa9f_8fb5a27db546 [GPO.GPO_aa217fba_9840_4176_98a6_e247cf0181c8, GPO.GPO_4189adb4_357e_45af_a3ca_e5f551e6554c]
# [] [GPO.GPO_ce7db854_9e14_4339_9e71_a8d4ab8f6331] https://gpo.ontology.link/GPO_f846eaba_e75a_49df_b71a_5f769e6a7e7e []
# [] [GPO.GPO_f95f16fd_4ee0_4fa9_be7f_1e562747adfd, emmo.EMMO_17e27c22_37e1_468c_9dd7_95e137f73e7f.some(GPO.GPO_39cf2373_f414_4295_92b8_7d60a91d7803)] https://gpo.ontology.link/GPO_18daa97a_afc7_4227_b197_38cd2c694e05 []
# [] [GPO.GPO_ab6f9ec2_2d58_4c67_b40b_1f454148ec35, emmo.EMMO_17e27c22_37e1_468c_9dd7_95e137f73e7f.some(GPO.GPO_23f6e14f_b0fa_4140_b915_767131ac9b7f)] https://gpo.ontology.link/GPO_39cf2373_f414_4295_92b8_7d60a91d7803 []
# [] [GPO.GPO_fb793a58_4083_42ad_a03c_27f594793b16] https://gpo.ontology.link/GPO_b28dc33d_0d96_4441_9686_7327becdcbc1 [GPO.GPO_3e188141_576f_43fc_8149_30c061fcb588, GPO.GPO_a1839bf6_9b67_48ca_a5a4_069b6e7fc0e9]
# [] [GPO.GPO_42631ff8_f9ce_408e_8446_99d5fd20dc6b, GPO.GPO_c6a4a988_b3c1_4a38_aa28_762cba34e3f0.some(GPO.GPO_42631ff8_f9ce_408e_8446_99d5fd20dc6b)] https://gpo.ontology.link/GPO_d03aba82_5af3_4553_9595_3883242b4564 []
# [] [GPO.GPO_f116ab16_8764_4fee_bd14_52990ef3bd40] https://gpo.ontology.link/GPO_bec0ac00_b4b6_492d_ba8a_08842aad2c5f [GPO.GPO_b268ec22_f7cb_49e3_879a_18c653660ada, GPO.GPO_328876a7_c599_47ba_848c_2024be809a35]
# [] [emmo.EMMO_1e877c70_3b01_45a8_a8f6_8ce4f6a24660] https://gpo.ontology.link/GPO_49677fd4_666a_483d_870b_30163391951a []
# [] [GPO.GPO_49fc895e_d6cf_4f12_bcc6_2ad94b75c212] https://gpo.ontology.link/GPO_560b54ed_de02_421d_b929_6fdc512a730f []
# [] [GPO.GPO_890abbc3_d75b_4f3f_a5b7_e1b0e898655b, emmo.EMMO_ae2d1a96_bfa1_409a_a7d2_03d69e8a125a.some(GPO.GPO_3ac98139_d8cd_431e_89b6_a624942ff16e)] https://gpo.ontology.link/GPO_6525ae89_1f2a_4426_adf0_4e142def29d1 []
# [] [GPO.GPO_c4600586_ccc8_4d4b_b7a2_123d5aa2d77d] https://gpo.ontology.link/GPO_890abbc3_d75b_4f3f_a5b7_e1b0e898655b [GPO.GPO_6525ae89_1f2a_4426_adf0_4e142def29d1]
# [] [GPO.GPO_aa217fba_9840_4176_98a6_e247cf0181c8] https://gpo.ontology.link/GPO_a32722d5_42c1_446f_a071_05071047831f []
# [] [GPO.GPO_8adf61b4_30a7_4beb_9af3_4859cee9f00f] https://gpo.ontology.link/GPO_6dff3494_5026_41ed_8247_cd1ce7e56b62 []
# [] [GPO.GPO_4690b12c_ad7a_4272_b9fd_aa6732ec91d4] https://gpo.ontology.link/GPO_8adf61b4_30a7_4beb_9af3_4859cee9f00f [GPO.GPO_6dff3494_5026_41ed_8247_cd1ce7e56b62, GPO.GPO_a1c93821_6eec_44f1_9323_acc7eb737650]
# [] [GPO.GPO_45b3677d_f436_4cfd_aa55_3ae5eab2e232, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.only(emmo.EMMO_a2b006f2_bbfd_4dba_bcaa_3fca20cd6be1)] https://gpo.ontology.link/GPO_81b0f5d9_15da_436d_bd62_9097f9c72e1f [GPO.GPO_57c4b094_e905_4307_9cdd_0db39e88e46d]
# [] [GPO.GPO_ce7db854_9e14_4339_9e71_a8d4ab8f6331] https://gpo.ontology.link/GPO_f48e1432_3ddd_4077_824f_fc664c72f7cf []
# [] [GPO.GPO_d84afb30_9eee_4c17_ab79_2de8895da4ad] https://gpo.ontology.link/GPO_c531bf8b_27fe_43c5_8b12_f12f73545b8a []
# [] [GPO.GPO_d25d869b_d2c9_467a_a8d1_6804453648b4] https://gpo.ontology.link/GPO_81050995_d110_4a80_b0fc_f81bc2f2e10d []
# [] [GPO.GPO_a7c0febc_0c12_4803_810a_f469c0d72e1c] https://gpo.ontology.link/GPO_d25d869b_d2c9_467a_a8d1_6804453648b4 [GPO.GPO_81050995_d110_4a80_b0fc_f81bc2f2e10d, GPO.GPO_3231f234_a167_42d8_a665_7415b5f55b5d]
# [] [GPO.GPO_01cd2578_8730_4ac9_a555_9112728ea939, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(GPO.GPO_2c787420_067a_483a_b565_a9a55898210e), GPO.GPO_8c869b47_a258_43b9_9c75_4285a80a1dfb.some(GPO.GPO_23f6e14f_b0fa_4140_b915_767131ac9b7f)] https://gpo.ontology.link/GPO_3af46bf2_9857_4102_a183_ab08d7cd6523 []
# [] [emmo.EMMO_494b372c_cfdf_47d3_a4de_5e037c540de8] https://gpo.ontology.link/GPO_11ea4fa0_cb4e_4a7e_94eb_f92962db03b9 []
# [] [GPO.GPO_4189adb4_357e_45af_a3ca_e5f551e6554c] https://gpo.ontology.link/GPO_e2b9e8d7_7af0_47c1_aefe_7b1bc77f1266 []
# [] [GPO.GPO_939ec66f_883f_41eb_aa9f_8fb5a27db546] https://gpo.ontology.link/GPO_4189adb4_357e_45af_a3ca_e5f551e6554c [GPO.GPO_e2b9e8d7_7af0_47c1_aefe_7b1bc77f1266, GPO.GPO_f535f871_95e7_46e2_8d62_f77bf9402987]
# [] [GPO.GPO_c6ed5569_2b1b_44b0_b7b8_1baaff6f2435] https://gpo.ontology.link/GPO_1973e87f_dcbd_449c_a108_fbb0a008c89b []
# [] [GPO.GPO_8678c374_5a0a_458d_b349_6339e6a9fd74] https://gpo.ontology.link/GPO_ecc98900_a7ff_4739_8542_1e6492c394bd []
# [] [GPO.GPO_01cd2578_8730_4ac9_a555_9112728ea939, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(GPO.GPO_0cbc43e8_d0d5_463f_97bb_c3d955f95ac1), GPO.GPO_8c869b47_a258_43b9_9c75_4285a80a1dfb.some(GPO.GPO_f01f7920_d7e2_4d5a_8470_e4bf5c60565a)] https://gpo.ontology.link/GPO_cc903d23_0d06_49f8_81e4_b7511d2587e9 []
# [] [GPO.GPO_8678c374_5a0a_458d_b349_6339e6a9fd74] https://gpo.ontology.link/GPO_ebae82b4_68e3_4566_9f0b_e859ebe53088 []
# [] [GPO.GPO_bec0ac00_b4b6_492d_ba8a_08842aad2c5f] https://gpo.ontology.link/GPO_b268ec22_f7cb_49e3_879a_18c653660ada []
# [] [GPO.GPO_bc07577b_1e4b_4d60_aa8d_3cfd09e7c03a] https://gpo.ontology.link/GPO_d89337ea_b7e4_4e81_a482_231aa25d1d39 []
# [] [GPO.GPO_6e556808_d24d_46f5_86eb_fdbbdc6e6ef1, emmo.EMMO_c7013b53_3071_410b_a5e4_a8d266dcdfb5] https://gpo.ontology.link/GPO_d30c62b5_4720_40b7_8c9d_0c43ef6a35f4 []
# [] [GPO.GPO_ef7f0705_2774_4db9_87b6_f3d2f16b1215] https://gpo.ontology.link/GPO_e4ba15be_8fe4_4f9e_9189_c9e762f86492 []
# [] [GPO.GPO_70b20870_3beb_414a_b91f_2b6d234fda1a] https://gpo.ontology.link/GPO_ef7f0705_2774_4db9_87b6_f3d2f16b1215 [GPO.GPO_e4ba15be_8fe4_4f9e_9189_c9e762f86492]
# [] [GPO.GPO_ee8c37fd_9f2c_4047_b25d_4149894bd7c0, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(GPO.GPO_a292bb5c_4596_48ac_8602_a3481bba5c05), GPO.GPO_8c869b47_a258_43b9_9c75_4285a80a1dfb.some(GPO.GPO_a292bb5c_4596_48ac_8602_a3481bba5c05), emmo.EMMO_ae2d1a96_bfa1_409a_a7d2_03d69e8a125a.some(GPO.GPO_6e556808_d24d_46f5_86eb_fdbbdc6e6ef1)] https://gpo.ontology.link/GPO_849a339d_834e_40c0_b19c_168bccbeacfb []
# [] [GPO.GPO_3ac98139_d8cd_431e_89b6_a624942ff16e] https://gpo.ontology.link/GPO_23dbb0cb_8928_4bf7_807d_a0af1d7d78c7 [GPO.GPO_858cfdad_246e_480a_b545_69686142211b]
# [] [GPO.GPO_a9d26d0b_c488_4349_a34b_fff146655267] https://gpo.ontology.link/GPO_1f42cf42_299b_43c4_8616_154920665540 []
# [] [GPO.GPO_f116ab16_8764_4fee_bd14_52990ef3bd40] https://gpo.ontology.link/GPO_a9d26d0b_c488_4349_a34b_fff146655267 [GPO.GPO_1f42cf42_299b_43c4_8616_154920665540]
# [] [GPO.GPO_01cd2578_8730_4ac9_a555_9112728ea939, GPO.GPO_aa602472_ba16_4375_b8b3_868f84324ec7, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(GPO.GPO_23f6e14f_b0fa_4140_b915_767131ac9b7f), GPO.GPO_8c869b47_a258_43b9_9c75_4285a80a1dfb.some(GPO.GPO_9471e306_144f_4310_82bf_1415d23326e0)] https://gpo.ontology.link/GPO_6167332b_8416_46c9_90d1_49ee7416ae24 []
# [] [emmo.EMMO_43e9a05d_98af_41b4_92f6_00f79a09bfce] https://gpo.ontology.link/GPO_aa602472_ba16_4375_b8b3_868f84324ec7 [GPO.GPO_6167332b_8416_46c9_90d1_49ee7416ae24]
# [] [GPO.GPO_6e556808_d24d_46f5_86eb_fdbbdc6e6ef1, emmo.EMMO_f94e509a_be29_4365_a4cd_70165e47e232] https://gpo.ontology.link/GPO_dcb10cbc_f367_4f9f_b2b2_fe11195a087c []
# [] [GPO.GPO_f116ab16_8764_4fee_bd14_52990ef3bd40] https://gpo.ontology.link/GPO_4823c56f_3708_4ddb_94b1_ccb928e65989 []
# [] [GPO.GPO_23dbb0cb_8928_4bf7_807d_a0af1d7d78c7] https://gpo.ontology.link/GPO_858cfdad_246e_480a_b545_69686142211b []
# [] [GPO.GPO_45b3677d_f436_4cfd_aa55_3ae5eab2e232, GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(emmo.EMMO_7509da43_56b1_4d7f_887a_65d1663df4ba), GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75.some(emmo.EMMO_a2b006f2_bbfd_4dba_bcaa_3fca20cd6be1)] https://gpo.ontology.link/GPO_ee89d1c9_bd1a_452d_bcf7_cd583af0369d []
# [] [GPO.GPO_bab79a61_029b_4d5f_9cb1_fe583bc17381] https://gpo.ontology.link/GPO_f352a440_5fbd_42c6_bff1_e70f0e652043 []
# [] [GPO.GPO_ac60cfc4_1500_41a4_9cf0_b5045155830e] https://gpo.ontology.link/GPO_bab79a61_029b_4d5f_9cb1_fe583bc17381 [GPO.GPO_f352a440_5fbd_42c6_bff1_e70f0e652043, GPO.GPO_19430518_1a88_4ad0_916a_c903fe807520, GPO.GPO_0597e385_8c91_4e7f_aa25_c75b5b9b80b6]
# [] [emmo.EMMO_c46f091c_0420_4c1a_af30_0a2c8ebcf7d7] https://gpo.ontology.link/GPO_ac60cfc4_1500_41a4_9cf0_b5045155830e [GPO.GPO_bab79a61_029b_4d5f_9cb1_fe583bc17381]
# [] [GPO.GPO_aa217fba_9840_4176_98a6_e247cf0181c8] https://gpo.ontology.link/GPO_275452d1_abaa_4c59_b4af_2f14332209c6 []
# [] [GPO.GPO_215e6bc2_1d8d_4ef1_a90d_8003b992b939, GPO.GPO_72ce86f4_f61d_4a79_86bd_1db6b4c6f270] https://gpo.ontology.link/GPO_56834535_1c08_447b_b2d0_63ad533b6bf9 []
# [] [GPO.GPO_7e0349b1_f5cd_4a61_ae5b_52441f61aa1b] https://gpo.ontology.link/GPO_ad83fdc3_f3ec_4037_b06f_1675a531f29f []
# [] [GPO.GPO_6dab7b9a_48f2_4ab2_b031_214d5ceac2d0, GPO.GPO_f3f83d9a_ad84_4ce0_aaec_a388f18cd681] https://gpo.ontology.link/GPO_d281ecac_c2e8_4ae7_a56c_d973a7d943d2 []
# [] [GPO.GPO_033b9632_cfc2_40fe_97c4_4e0587ab4ec8, GPO.GPO_285d777d_6e73_444f_9a10_03983157b457] https://gpo.ontology.link/GPO_66366e89_4a13_4996_b887_a127e498ed98 []
# [] [GPO.GPO_48094cc5_05e6_4f0b_b8c2_5561497f8a8e] https://gpo.ontology.link/GPO_285d777d_6e73_444f_9a10_03983157b457 [GPO.GPO_66366e89_4a13_4996_b887_a127e498ed98]
# [] [GPO.GPO_72ce86f4_f61d_4a79_86bd_1db6b4c6f270, GPO.GPO_c5952e89_2710_4dfd_b87a_82d99cc6823b] https://gpo.ontology.link/GPO_99ef5665_e946_485d_b3ba_87e300564a95 []
# [] [GPO.GPO_b28dc33d_0d96_4441_9686_7327becdcbc1] https://gpo.ontology.link/GPO_3e188141_576f_43fc_8149_30c061fcb588 []
# [] [GPO.GPO_b28dc33d_0d96_4441_9686_7327becdcbc1] https://gpo.ontology.link/GPO_a1839bf6_9b67_48ca_a5a4_069b6e7fc0e9 []
# [] [GPO.GPO_bec0ac00_b4b6_492d_ba8a_08842aad2c5f] https://gpo.ontology.link/GPO_328876a7_c599_47ba_848c_2024be809a35 []
# [] [GPO.GPO_6fd96cfe_e99e_4030_95db_0a72b47865d4, GPO.GPO_c6a4a988_b3c1_4a38_aa28_762cba34e3f
# [] [GPO.GPO_8adf61b4_30a7_4beb_9af3_4859cee9f00f] https://gpo.ontology.link/GPO_a1c93821_6eec_44f1_9323_acc7eb737650 []
# [] [GPO.GPO_8678fb81_bb19_494c_ac8e_67a0ee65b0db] https://gpo.ontology.link/GPO_06512cb1_63cc_493a_84fd_44551b94d88b []
# [] [GPO.GPO_bab79a61_029b_4d5f_9cb1_fe583bc17381] https://gpo.ontology.link/GPO_0597e385_8c91_4e7f_aa25_c75b5b9b80b6 []
# [] [GPO.GPO_b10580a1_fb72_4151_a573_bbef22bae02b] https://gpo.ontology.link/GPO_c8e0ab0c_1a3d_4184_969e_5476ab0bb36d []
# [] [GPO.GPO_c4600586_ccc8_4d4b_b7a2_123d5aa2d77d] https://gpo.ontology.link/GPO_bfaebe5c_1b0a_49d4_bf14_94e8d0546197 []
# [] [GPO.GPO_8678fb81_bb19_494c_ac8e_67a0ee65b0db] https://gpo.ontology.link/GPO_927388fd_eb32_4c1f_9a58_ee41a6ed55a4 []
# [] [owl.Thing] https://w3id.org/emmo#EMMO_68390bfb_e307_479d_8f78_d66d8773cb1d []
#
# Object Properties:
# GPO.GPO_703ec528_ea40_486e_9924_b911782b1a75
# emmo.EMMO_ae2d1a96_bfa1_409a_a7d2_03d69e8a125a
# GPO.GPO_8c869b47_a258_43b9_9c75_4285a80a1dfb
# GPO.GPO_39014ab3_e461_444a_a4a7_a0361550f800
# GPO.GPO_869d7b15_2918_4064_be6b_241d4f7dc79e
# emmo.EMMO_6703954e_34c4_4a15_a9e7_f313760ae1a8
# GPO.GPO_25f1a7da_895c_4d9b_b688_95b7deed7a80
# GPO.GPO_c6a4a988_b3c1_4a38_aa28_762cba34e3f0
# GPO.GPO_389686f5_86d8_4e97_ba71_0537bedf0f38
# GPO.GPO_d52245e5_8dca_4a0f_bed8_0c7665da4560
# GPO.GPO_e5028661_972c_4977_947b_29a744f5e893
# emmo.EMMO_17e27c22_37e1_468c_9dd7_95e137f73e7f
# emmo.EMMO_9a084aa3_3d5a_4a62_9fc0_fd88937a19c5
# GPO.GPO_d9f99371_6c00_41a0_9676_bbb150b317fb
# GPO.GPO_0c25c011_9320_461f_bc23_6e9691827305
# GPO.GPO_2d23e608_57f5_4d0d_ba4e_c06ab274e101
# GPO.GPO_b03e856b_3316_422f_99f3_af4c96fd406a

# %%
from emmopy.emmocheck import *

# %%
emmo_url = (
        'https://raw.githubusercontent.com/emmo-repo/emmo-repo.github.io/'
        'master/versions/1.0.0-beta/emmo-inferred-chemistry2.ttl')
world = World()
emmo = world.get_ontology(emmo_url)
emmo.load()
emmo.sync_python_names()  # Syncronize annotations
emmo.base_iri = emmo.base_iri.rstrip('/#')
catalog_mappings = {emmo.base_iri: emmo_url}

# Create new ontology
onto = world.get_ontology('http://emmo.info/domain-atomistic#')
onto.imported_ontologies.append(emmo)
onto.sync_python_names()
# Out:
# get_ontology("http://emmo.info/domain-atomistic#")

# %%
#!/usr/bin/env python
"""Python script that generates the periodic table ontology.
"""
from ontopy.ontology import World
from ontopy.utils import write_catalog
import owlready2


__version__ = "0.0.1"  # Version of this ontology


def en(s):
    """Returns `s` as an English location string."""
    return owlready2.locstr(s, lang='en')


def pl(s):
    """Returns `s` as a plain literal string."""
    return owlready2.locstr(s, lang='')


# Load crystallography, which imports emmo
emmo_url = (
        'https://raw.githubusercontent.com/emmo-repo/emmo-repo.github.io/'
        'master/versions/1.0.0-beta/emmo-inferred-chemistry2.ttl')
world = World()
emmo = world.get_ontology(emmo_url)
emmo.load()
emmo.sync_python_names()  # Syncronize annotations
emmo.base_iri = emmo.base_iri.rstrip('/#')
catalog_mappings = {emmo.base_iri: emmo_url}

# Create new ontology
onto = world.get_ontology('http://emmo.info/domain-atomistic#')
onto.imported_ontologies.append(emmo)
onto.sync_python_names()


# Populate the new ontology
with onto:

    #
    # ObjectProperties
    # ----------------
    class hasEigenvalue(onto.hasProperty):
        """Relates a mathematical (or physical) operator to its eigenvalue."""
        domain = [onto.MathematicalOperator]

    #
    # Classes
    # -------
    class ChargeDensity(onto.ISQDerivedQuantity):
        """Electric charge per volume."""
        physicalDimension = pl("T+1 L-3 M0 I+1 Θ0 N0 J0")
        IECEntry = pl("http://www.electropedia.org/iev/iev.nsf/display?"
                      "openform&ievref=121-11-07")
        iupacEntry = pl("https://doi.org/10.1351/goldbook.C00988")
        omMatch = pl("http://www.ontology-of-units-of-measure.org/resource/"
                     "om-2/ElectricChargeDensity")
        wikipediaEntry = "https://en.wikipedia.org/wiki/Charge_density"

    class ChargeDensityDimension(onto.PhysicalDimension):
        """Physical dimensionality of charge density."""
        equivalent_to = [onto.hasSymbolData.value(
            pl("T+1 L-3 M0 I+1 Θ0 N0 J0"))]

    class DensityFunctionalTheory(onto.ElectronicModel):
        """An efficient computional method for solving the many-electron
        (time-independent) Schrödinger equation."""

    class PhysicalOperator(onto.MathematicalOperator):
        """A mathematical operator with a physical interpretation."""

    class Hamiltonian(onto.PhysicalOperator):
        """An operator corresponding to the sum of the kinetic energies plus
        the potential energies for all the particles in the system."""
        is_a = [onto.Object, onto.hasEigenvalue.some(onto.Energy)]

    class WaveFunction(onto.ISQDimensionlessQuantity):
        """A mathematical description of the quantum state of an isolated
        quantum system. A wave function is a function of the degrees
        of freedom corresponding to some maximal set of commuting
        observables. Once such a representation is chosen, the wave
        function can be derived from the quantum state.
        """
        physicalDimension = pl("T0 L0 M0 I0 Θ0 N0 J0")
        wikipediaEntry = pl("https://en.wikipedia.org/wiki/Wave_function")

    class SchrodingerEquation(onto.PhysicsEquation):
        """A linear partial differential equation describing the wave
        function of a quantum-mechanical system.

        The exact form of the Schrödinger equation depends on the
        physical situation.  The most general form is the
        time-dependent Schrödinger equation.
        """
        altLabel = en("SchrödingerEquation")
        is_a = [onto.hasSpatialDirectPart.some(onto.Energy),
                onto.hasSpatialDirectPart.some(onto.Hamiltonian),
                onto.hasSpatialDirectPart.some(onto.WaveFunction)]
        wikipediaEntry = pl(
            "https://en.wikipedia.org/wiki/Schr%C3%B6dinger_equation")

    class TimeDependentSchrodingerEquation(onto.SchrodingerEquation):
        """The full time-dependent Schrödinger equation."""
        altLabel = en("TimeDependentSchrödingerEquation")

    class TimeIndependentSchrodingerEquation(onto.SchrodingerEquation):
        """If the external potential does not depende on time, the Schrödinger
        equation can be reduced to this time-independent form.
        """
        altLabel = en("TimeIndependentSchrödingerEquation")

    class KohnShamEquation(onto.TimeIndependentSchrodingerEquation):
        """The Schrödinger equation for a fictious "Kohn-Sham" system of
        non-interacting electrons that generates the same charge
        density as the real interacting system.
        """
        comment = ("This is the equation that is solved with density "
                   "functional theory.")
        is_a = [onto.hasSpatialDirectPart.some(onto.ChargeDensity)]


# Save new ontology as owl
onto.sync_attributes(name_policy='uuid', class_docstring='elucidation',
                     name_prefix='')
version_iri = "http://emmo.info/%s/domain-atomistic" % __version__
onto.set_version(version_iri=version_iri)
onto.dir_label = False

catalog_mappings[version_iri] = 'atomistic.ttl'

#################################################################
# Annotate the ontology metadata
#################################################################

onto.metadata.abstract.append(en(
        'An EMMO-based domain ontology for atomistic and electronic modelling.'
        'Atomistic is released under the Creative Commons Attribution 4.0 '
        'International license (CC BY 4.0).'))

onto.metadata.title.append(en('Atomistic'))
onto.metadata.creator.append(en('Jesper Friis'))
onto.metadata.contributor.append(en('SINTEF'))
onto.metadata.creator.append(en('Francesca L. Bleken'))
onto.metadata.contributor.append(en('SINTEF'))
onto.metadata.publisher.append(en('EMMC ASBL'))
onto.metadata.license.append(en(
    'https://creativecommons.org/licenses/by/4.0/legalcode'))
onto.metadata.versionInfo.append(en(__version__))
onto.metadata.comment.append(en(
    'The EMMO requires FaCT++ reasoner plugin in order to visualize all'
    'inferences and class hierarchy (ctrl+R hotkey in Protege).'))
onto.metadata.comment.append(en(
    'This ontology is generated with data from the ASE Python package.'))
onto.metadata.comment.append(en(
    'Contacts:\n'
    'Jesper Friis\n'
    'SINTEF\n'
    'email: jesper.friis@sintef.no\n'
    '\n'
    'Francesca L. Bleken\n'
    'SINTEF\n'
    'email: francesca.l.bleken@sintef.no'
    ))


onto.save('atomistic.ttl', overwrite=True)
write_catalog(catalog_mappings)
# onto.sync_reasoner()
# onto.save('atomistic-inferred.ttl', overwrite=True)


# Manually change url of EMMO to `emmo_url` when importing it to make
# it resolvable without consulting the catalog file.  This makes it possible
# to open the ontology from url in Protege
import rdflib  # noqa: E402, F401
g = rdflib.Graph()
g.parse('atomistic.ttl', format='turtle')
for s, p, o in g.triples(
        (None, rdflib.URIRef('http://www.w3.org/2002/07/owl#imports'), None)):
    if 'emmo-inferred' in o:
        g.remove((s, p, o))
        g.add((s, p, rdflib.URIRef(emmo_url)))
g.serialize(destination='atomistic.ttl', format='turtle')
# Out:
# <Graph identifier=N9f6b79502d3e4eccbfa9b26ab270b397 (<class 'rdflib.graph.Graph'>)>
