# %%
#https://motius.breezy.hr/p/0b622aa1163e01-join-our-tech-community-as-working-student-m-f-d/apply?utm_source=pt-linkedin&utm_medium=job-posting

# %%
from transformers import  AutoModel,AutoTokenizer,AutoModelForMaskedLM , Trainer,TrainingArguments,\
BitsAndBytesConfig,pipeline,default_data_collator,DataCollatorWithPadding,DataCollatorForLanguageModeling
from transformers.utils import move_cache
from chat_template_utils import get_json_schema
from llama_cpp import Llama
from utils import *
from peft import *
import datasets
from datasets import Features, Value
import torchmetrics
import torch
from torch.utils.data.dataloader import DataLoader,Dataset
from hqq.engine.hf import HQQModelForCausalLM
from hqq.models.hf.base import AutoHQQHFModel
from huggingface_hub import snapshot_download
#import deepspeed
import os
import pandas as pd
import json
from var_dump import var_dump
from bs4 import BeautifulSoup,PageElement,Comment
import matplotlib.pyplot as plt
import seaborn as sns

cache_dir='/var/tmp/.cache/' #'/proj/ciptmp/ix05ogym/.cache/'
output_dir = cache_dir+'outputs/'

move_cache(cache_dir)
# Out:
# No ROCm runtime is found, using ROCM_HOME='/usr'
# /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 0it [00:00, ?it/s]

# %%
train_dataset = pd.read_excel('./data/train_forms.xlsx')[['input_text','labels']]
train_dataset.drop_duplicates(['input_text']).reset_index(drop=True)
c = train_dataset['labels']=='other'
train_dataset.loc[c,'labels']=pd.NA
c = train_dataset['labels']=='birthdate'
train_dataset.loc[c,'labels']='birth'

train_dataset['labels'].unique()

#c = train_dataset['labels']=='privacy'
#train_dataset.loc[c,:]

lll=[]
person = {"first name":"majid","last name":"sharghi foroushani","pronoun":"he","birth":"10/08/1997","age":"27","sex":"male","skill":"NLP,LLM","country":"Germany","address":"Philip-9","city":"Erlangen","phone number":"+497773154","available from":"6/24/2024","salary":"10000","German language level":"A1","English language level":"C1","visa":"do not need visa","email":"sharghi.majid@gmail.com","password":"123456","find us":"Google","xing":"www.xing.com","job":"I am stduent","university":"FAU","major":"AI","privacy":"privacy","search":"search","submit":"submit","cookie":"cookie","cover letter":"cover letter","linkedin":"www.linkedin.com","github":"www.github.com","login":"login","register":"register","cv":"/pah/to/cv.pdf","twitter":"www.twitter.com"}
for k,v in person.items():
    c =  train_dataset['labels']==k
    #train_dataset.loc[c,'labels']=k
    pass
    
print(train_dataset['labels'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_dataset = pd.read_excel('./data/train_forms.xlsx')[['input_text','labels']]
#       2 train_dataset.drop_duplicates(['input_text']).reset_index(drop=True)
#       3 c = train_dataset['labels']=='other'
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['labels'] not in index"

# %%
test_dataset = pd.read_excel('./data/forms.xlsx')
c = test_dataset['label'].notna()
test_dataset = test_dataset.loc[c,:].reset_index(drop=True)
test_dataset['label'].unique()
# Out:
# array(['cv', 'first name', 'last name', 'email', 'phone number',
#        'available from', 'github', 'privacy', 'submit', 'search',
#        'country', 'sex', 'zip', 'cover letter', 'linkedin', 'visa',
#        'xing', 'newsletter'], dtype=object)

# %%
test_dataset
# Out:
#                                                 query  \
# 0   Personal information\n CV or resume\n Browse C...
# 1                                           Name *\n
# 2           This field contains invalid characters\n
# 3   This field contains invalid characters\n Email...
# 4                                            Phone\n
# ..                                                ...
# 95         cover letter\n upload your cover letter\n
# 96                                          github\n
# 97                             ihre e-mail-adresse\n
# 98                    (!)\n this field is required\n
# 99        this field is required\n from device\n *\n
#
#                                               element         label  \
# 0   <input accept="application/pdf,.pdf" name="cv"...            cv
# 1   <input name="first_name" placeholder="First" r...    first name
# 2   <input name="last_name" placeholder="Last" req...     last name
# 3   <input name="email" placeholder="yourmail@doma...         email
# 4   <input name="phone" placeholder="+49 176 123 4...  phone number
# ..                                                ...           ...
# 95  <input accept="application/msword, application...  cover letter
# 96  <input name="custom_attribute_356304" placehol...        github
# 97  <button aria-label="subscribe for newsletter" ...    newsletter
# 98  <button id="uploaddropboxresume" type="submit"...        submit
# 99  <input accept=".pdf,.doc,.docx,.txt" aria-requ...            cv
#
#       sudo_label
# 0          login
# 1     first name
# 2     transcript
# 3          email
# 4   phone number
# ..           ...
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
#
# [100 rows x 4 columns]

# %%
from sentence_transformers  import SentenceTransformer
#from transformers import AutoModel
model_name= 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'
#sentence-transformers/all-MiniLM-L12-v2
embdeding_tokenizer = AutoTokenizer.from_pretrained(model_name,cache_dir=cache_dir)

#embeding_model= AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L12-v2',cache_dir=cache_dir)#.to('cuda')
embeding_model= SentenceTransformer(model_name,cache_folder=cache_dir)#.to('cuda')
#guide_model= SentenceTransformer(model_name,cache_folder=cache_dir)#.to('cuda')



embeding_model.eval()
embeding_model
# Out:
# /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
# )

# %%
data = pd.read_excel('./data/query_element_4.xlsx')
data
# Out:
#                                                   query  \
# 0                                              keywords
# 1                                         Email Address
# 2     Please tick to confirm that you consent to us ...
# 3     which includes details on how you can withdraw...
# 4                                             Subscribe
# ...                                                 ...
# 1586  Please identify your race Please selectAmerica...
# 1587                       Race & Ethnicity Definitions
# 1588  Veteran Status Please selectI am not a protect...
# 1589  Completing this form is voluntary, and we hope...
# 1590  Disability Status Please selectYes, I have a d...
#
#                                                 element  \
# 0     <input autocomplete="off" autofocus="" id="aut...
# 1     <input id="fieldEmail" name="cm-ukutgu-ukutgu"...
# 2     <a href="/privacy-policy" target="_blank" titl...
# 3     <input name="gdpr_verification" required="" ty...
# 4              <button type="submit">Subscribe</button>
# ...                                                 ...
# 1586  <select aria-required="false" id="job_applicat...
# 1587  <a href="https://boards.cdn.greenhouse.io/docs...
# 1588  <select aria-required="false" id="job_applicat...
# 1589  <a href="https://www.dol.gov/ofccp" target="_b...
# 1590  <select aria-required="false" id="job_applicat...
#
#                                  answer      label
# 0                                   NaN        NaN
# 1               sharghi.majid@gmail.com      email
# 2                               privacy    privacy
# 3                                cookie     cookie
# 4                             subscribe  subscribe
# ...                                 ...        ...
# 1586  American Indian or Alaskan Native  ethnicity
# 1587                                 A1  ethnicity
# 1588       I am not a protected veteran        NaN
# 1589          https://www.dol.gov/ofccp        NaN
# 1590                                NaN        NaN
#
# [1591 rows x 4 columns]

# %%
#embeding_model = get_peft_model(embeding_model,LoraConfig(target_modules=['query','value']))
#embeding_model.print_trainable_parameters()

# %%
#c = train_dataset['labels']=='relocate'
#train_dataset.loc[c,'labels'] = 'willing to relocate'
#train_dataset[c]

# %%
#train_dataset.to_excel('train_forms.xlsx',index=0)

# %%
from sentence_transformers.trainer import SentenceTransformerTrainer,SentenceTransformerTrainingArguments
#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# %%
c = data['label'].notna()
data = data[c].reset_index(drop=True)
u = data['label'].unique()
id2key = dict(enumerate(u))
key2id = dict(zip(u,range(len(u))))
key2id

data.loc[:,'label'] = data['label'].map(lambda x:key2id[ x ])

# %%
#data.loc[:,'label']=1
features = Features({
    'query': Value('string'),
    'element': Value('string'),
    'answer': Value('string'),
    'label': Value('int64')
})
train_dataset = datasets.Dataset.from_pandas(data,features)

train_dataset = train_dataset.remove_columns(['answer','query'])#,'label'])
train_dataset
# Out:
# Dataset({
#     features: ['element', 'label'],
#     num_rows: 1082
# })

# %%
train_dataset[0]
# Out:
# {'element': '<input id="fieldEmail" name="cm-ukutgu-ukutgu" required="" type="email"/>',
#  'label': 0}

# %%
from sentence_transformers.losses import BatchSemiHardTripletLoss as myloss
trainer  =  SentenceTransformerTrainer(model=embeding_model,
                           train_dataset=train_dataset,
                           tokenizer=embdeding_tokenizer,
                           loss= myloss(embeding_model)#,384,len(u)),#,'sentence-transformers/all-MiniLM-L12-v2',True),
                           ,args=SentenceTransformerTrainingArguments(
                               output_dir=output_dir,
                               num_train_epochs=30,
                               per_device_train_batch_size=32,
                               logging_steps=10
                           )
                           
                           )


trainer.train()
# Out:
# [2024-07-11 14:06:06,004] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# Warning: The default cache directory for DeepSpeed Triton autotune, /home/cip/ce/ix05ogym/.triton/autotune, appears to be on an NFS system. While this is generally acceptable, if you experience slowdowns or hanging when DeepSpeed exits, it is recommended to set the TRITON_CACHE_DIR environment variable to a non-NFS path.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.3
#  [WARNING]  using untested triton version (2.3.1), only 1.0.0 is known to be compatible
#     <div>
#
#       <progress value='131' max='1020' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 131/1020 00:14 < 01:41, 8.74 it/s, Epoch 3.82/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.359800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.441200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>3.447300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.376500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.710400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.479300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.621800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.283800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.311000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.834300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.623900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.551000</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#       1 from sentence_transformers.losses import BatchSemiHardTripletLoss as myloss
#       2 trainer  =  SentenceTransformerTrainer(model=embeding_model,
#       3                            train_dataset=train_dataset,
#       4                            tokenizer=embdeding_tokenizer,
#    (...)
#      12
#      13                            )
# ---> 16 trainer.train()
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/transformers/trainer.py:1885, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1883         hf_hub_utils.enable_progress_bars()
#    1884 else:
# -> 1885     return inner_training_loop(
#    1886         args=args,
#    1887         resume_from_checkpoint=resume_from_checkpoint,
#    1888         trial=trial,
#    1889         ignore_keys_for_eval=ignore_keys_for_eval,
#    1890     )
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/transformers/trainer.py:2216, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2213     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2215 with self.accelerator.accumulate(model):
# -> 2216     tr_loss_step = self.training_step(model, inputs)
#    2218 if (
#    2219     args.logging_nan_inf_filter
#    2220     and not is_torch_xla_available()
#    2221     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2222 ):
#    2223     # if loss is nan or inf simply add the average of previous logged losses
#    2224     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/transformers/trainer.py:3250, in Trainer.training_step(***failed resolving arguments***)
#    3248         scaled_loss.backward()
#    3249 else:
# -> 3250     self.accelerator.backward(loss)
#    3252 return loss.detach() / self.args.gradient_accumulation_steps
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/accelerate/accelerator.py:2134, in Accelerator.backward(self, loss, **kwargs)
#    2132     self.lomo_backward(loss, learning_rate)
#    2133 else:
# -> 2134     loss.backward(**kwargs)
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File /proj/ciptmp/ix05ogym/myenv/lib/python3.11/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
#c = test_dataset['query'].isna()
#test_dataset.loc[c,'query']='cv'
#test_dataset.to_excel('forms.xlsx',index=0)

# %%
test_dataset = pd.read_excel('forms.xlsx')
c = test_dataset['label'].notna()
test_dataset = test_dataset.loc[c,:].reset_index(drop=True)

tp = test_dataset #train_dataset.to_pandas()
def compute_metric():
    embeding_model.eval()
    acc=0
    
    with torch.no_grad():
        
        l=embeding_model.encode(LABEL_INDEX_TO_KEY)
        l = torch.tensor(l)
        print(l.shape)
        
        for i,x in tp.iterrows():
            #print(x)
            #for i,x in train_dataset.iterrows():
            #te = embdeding_tokenizer([x['element']],max_length=512,truncation=True,return_tensors='pt')['input_ids']
            #print(i)
            #x['label']
            o = embeding_model.encode( [x['query']] )
            o2 = embeding_model.encode( x['element'] )
            
            o = torch.tensor(o)
            o2 = torch.tensor(o2)
            
            sim = torch.cosine_similarity(l,o)
            #print(o2.shape)
            #sim = torch.cosine_similarity(o2,o,0)

            m = sim.argmax()
            tp.loc[i,'sudo_label']=LABEL_INDEX_TO_KEY[m]
            #tp.loc[i,'sudo_label_value']=sim
            if LABEL_INDEX_TO_KEY[m]==x['label']:
                acc+=1
                pass
            #print(LABEL_INDEX_TO_KEY[sim.argmax()],x['label'])
            
           
             
    
    acc/=len(test_dataset)
    print("acc:",acc)
    
    
    
compute_metric()
# Out:
# torch.Size([61, 384])
# acc: 0.43

# %%
test_dataset.loc[11,'query']='cv *'
tp
# Out:
#                                                 query  \
# 0   Personal information\n CV or resume\n Browse C...
# 1                                           Name *\n
# 2           This field contains invalid characters\n
# 3   This field contains invalid characters\n Email...
# 4                                            Phone\n
# ..                                                ...
# 95         cover letter\n upload your cover letter\n
# 96                                          github\n
# 97                             ihre e-mail-adresse\n
# 98                    (!)\n this field is required\n
# 99        this field is required\n from device\n *\n
#
#                                               element         label  \
# 0   <input accept="application/pdf,.pdf" name="cv"...            cv
# 1   <input name="first_name" placeholder="First" r...    first name
# 2   <input name="last_name" placeholder="Last" req...     last name
# 3   <input name="email" placeholder="yourmail@doma...         email
# 4   <input name="phone" placeholder="+49 176 123 4...  phone number
# ..                                                ...           ...
# 95  <input accept="application/msword, application...  cover letter
# 96  <input name="custom_attribute_356304" placehol...        github
# 97  <button aria-label="subscribe for newsletter" ...    newsletter
# 98  <button id="uploaddropboxresume" type="submit"...        submit
# 99  <input accept=".pdf,.doc,.docx,.txt" aria-requ...            cv
#
#       sudo_label
# 0         github
# 1     first name
# 2        pronoun
# 3          email
# 4   phone number
# ..           ...
# 95  cover letter
# 96        github
# 97         email
# 98       find us
# 99       privacy
#
# [100 rows x 4 columns]

# %%
for i,x in tp.iterrows():
            print(x['query'])
            print(x['element'])
            print(x['sudo_label'])
            #print(x['sudo_label_value'])
            print('-----------------------------------')
# Out:
# Personal information
#  CV or resume
#  Browse CV to autocomplete your application. You can still fill your profile manually.
#
# <input accept="application/pdf,.pdf" name="cv" tabindex="-1" type="file"/>
# github
# -----------------------------------
# Name *
#
# <input name="first_name" placeholder="First" required="" type="text"/>
# first name
# -----------------------------------
# This field contains invalid characters
#
# <input name="last_name" placeholder="Last" required="" type="text"/>
# pronoun
# -----------------------------------
# This field contains invalid characters
#  Email *
#
# <input name="email" placeholder="yourmail@domain.com" required="" type="email"/>
# email
# -----------------------------------
# Phone
#
# <input name="phone" placeholder="+49 176 123 4455" type="text"/>
# phone number
# -----------------------------------
# Available from *
#
# <input name="available_from" placeholder="" required="" type="text"/>
# available from
# -----------------------------------
# GitHub
#
# <input name="custom_attribute_529055" placeholder="" type="text"/>
# github
# -----------------------------------
# Documents
#  Please upload your CV, a short cover letter, and optional
#  recent certificates
#  (max. 20 MB in total).
#  CV *
#  Click to select multiple files or use drag-and-drop
#  Cover letter
#  Click to select multiple files or use drag-and-drop
#  Other
#  Click to select multiple files or use drag-and-drop
#  *
#
# <input id="privacy-policy-acceptance" name="privacy-policy-acceptance" required="" type="checkbox"/>
# transcript
# -----------------------------------
# I hereby confirm that I have read and understood the
#
# <a data-locale="en" href="javascript:void();"> Data privacy statement</a>
# website language
# -----------------------------------
# .
#  *
#  Uploading document. Please wait.
#
# <button disabled="" type="submit">Send application </button>
# transcript
# -----------------------------------
# Email
#  *
#
# <input autocomplete="email" data-testid="TextInput" id="email" name="email" required="" type="email" value=""/>
# email
# -----------------------------------
# cv *
# <button type="button">CV * </button>
# cv
# -----------------------------------
# and confirm that I've reviewed the
#
# <a data-testid="Link" href="https://join.com/privacy-policy" rel="noopener" target="_blank">Privacy Policy </a>
# search
# -----------------------------------
# .
#
# <button type="submit">Apply now </button>
# email
# -----------------------------------
# Telephone Number (Mobile/Work)
#
# <input id="form-field-field_07a6a9e" name="form_fields[field_07a6a9e]" pattern="[0-9()#&amp;+*-=.]+" placeholder="+44" size="1" title="Only numbers and phone characters (#, -, *, etc) are accepted." type="tel"/>
# phone number
# -----------------------------------
# No
#
# <button type="submit">Submit Application </button>
# find us
# -----------------------------------
# Open link in a new tab
#  Or link to existing content
#  Search
#
# <input aria-describedby="wplink-link-existing-content" autocomplete="off" id="wp-link-search" type="search"/>
# search
# -----------------------------------
# Country
#
# <select id="optionsFacetsDD_country" name="optionsFacetsDD_country"><option value="">All </option></select>
# country
# -----------------------------------
# Search by Keyword
#
# <input aria-label="Search by Keyword" maxlength="50" name="q" placeholder="Search by Keyword" type="text"/>
# search
# -----------------------------------
# Search by Location
#
# <input aria-label="Search by Location" maxlength="50" name="locationsearch" placeholder="Search by Location" type="text"/>
# search
# -----------------------------------
# Country/Region
#
# <select id="optionsFacetsDD_country" name="optionsFacetsDD_country"><option value=""> All</option></select>
# country
# -----------------------------------
# und die
#
# <a data-cy="privacy" href="/datenschutz" rel="noreferrer" target="_blank">Datenschutzerklärung </a>
# find us
# -----------------------------------
# Phone *
#
# <input name="phone" placeholder="+49 176 123 4455" required="" type="text"/>
# phone number
# -----------------------------------
# Gender
#
# <select data-target="#gender" name="gender" placeholder="Please select …"><option selected="selected" value=""> Please select …</option><option value="male"> Male</option><option value="female"> Female</option><option value="diverse"> Diverse</option><option value="undefined"> Undefined</option></select>
# sex
# -----------------------------------
# Please do not exceed 60 characters.
#  Last Name
#  *
#
# <input aria-describedby="help-block_last_name_3 apply-description-last_name_3" aria-labelledby="label_last_name_3" aria-required="true" id="last_name_3" name="last_name" type="text"/>
# last name
# -----------------------------------
# Please do not exceed 120 characters.
#  ZIP Code
#  *
#
# <input aria-describedby="help-block_zip_7 apply-description-zip_7" aria-labelledby="label_zip_7" aria-required="true" id="zip_7" name="zip" type="text"/>
# zip
# -----------------------------------
# Please do not exceed 20 characters.
#  Country
#
# <select aria-describedby="help-block_country_8 apply-description-country_8" aria-labelledby="label_country_8" aria-required="false" id="country_8" name="country"><option value=""> --Please Select--</option><option value="country_afghanistan"> Afghanistan</option><option value="country_albania"> Albania</option><option value="country_algeria"> Algeria</option><option value="country_andorra"> Andorra</option><option value="country_angola"> Angola</option><option value="country_antigua"> Antigua</option><option value="country_argentina"> Argentina</option><option value="country_armenia"> Armenia</option><option value="country_aruba"> Aruba</option><option value="country_australia"> Australia</option><option value="country_austria"> Austria</option><option value="country_azerbaijan"> Azerbaijan</option><option value="country_bahamas"> Bahamas</option><option value="country_bahrain"> Bahrain</option><option value="country_bangladesh"> Bangladesh</option><option value="country_barbados"> Barbados</option><option value="country_belarus"> Belarus</option><option value="country_belgium"> Belgium</option><option value="country_belize"> Belize</option><option value="country_benin"> Benin</option><option value="country_bermuda"> Bermuda</option><option value="country_bhutan"> Bhutan</option><option value="country_bolivia"> Bolivia</option><option value="country_bosnia_herzegovina"> Bosnia Herzegovina</option><option value="country_botswana"> Botswana</option><option value="country_brazil"> Brazil</option><option value="country_brunei_darussalam"> Brunei Darussalam</option><option value="country_bulgaria"> Bulgaria</option><option value="country_burkina_faso"> Burkina Faso</option><option value="country_burundi"> Burundi</option><option value="country_cambodia"> Cambodia</option><option value="country_cameroon"> Cameroon</option><option value="country_canada"> Canada</option><option value="country_cape_verde"> Cape Verde</option><option value="country_cayman_islands"> Cayman Islands</option><option value="country_central_african_rep"> Central African Rep</option><option value="country_chad"> Chad</option><option value="country_chile"> Chile</option><option value="country_china"> China Mainland</option><option value="country_colombia"> Colombia</option><option value="country_comoros"> Comores</option><option value="country_congo"> Congo</option><option value="country_cook_islands"> Cook Islands</option><option value="country_costa_rica"> Costa Rica</option><option value="country_croatia"> Croatia</option><option value="country_cuba"> Cuba</option><option value="country_cyprus"> Cyprus</option><option value="country_czech_republic"> Czech Republic</option><option value="country_dem_rep_congo"> Democratic Republic of the Congo</option><option value="country_denmark"> Denmark</option><option value="country_djibouti"> Djibouti</option><option value="country_dominica"> Dominica</option><option value="country_dominican_republic"> Dominican Republic</option><option value="country_ecuador"> Ecuador</option><option value="country_egypt"> Egypt</option><option value="country_el_salvador"> El Salvador</option><option value="country_equatorial_guinea"> Equatorial Guinea</option><option value="country_eritrea"> Eritrea</option><option value="country_estonia"> Estonia</option><option value="country_ethiopia"> Ethiopia</option><option value="country_falkland_islands"> Falkland Islands</option><option value="country_faroe_islands"> Faroe Islands</option><option value="country_fiji"> Fiji</option><option value="country_finland"> Finland</option><option value="country_france"> France</option><option value="country_frenchguiana"> French Guiana</option><option value="country_frenchpolynesia"> French Polynesia</option><option value="country_gabon"> Gabon</option><option value="country_gambia"> Gambia</option><option value="country_georgia"> Georgia</option><option value="country_germany"> Germany</option><option value="country_ghana"> Ghana</option><option valu ...
# country
# -----------------------------------
# Data successfully submitted
#  Attached CV
#  *
#  Attached CV
#  *
#  add file
#
# <button aria-describedby="help-block_attached_resume_17 label_attached_resume_17 upload_btn_valueattached_resume_17 apply-description-attached_resume_17" id="upload_btn_attached_resume_17" type="button"> add file</button>
# transcript
# -----------------------------------
# Data successfully submitted
#  Attached Cover Letter
#  Attached Cover Letter
#  add file
#
# <button aria-describedby="help-block_cover_letter_22 label_cover_letter_22 upload_btn_valuecover_letter_22 apply-description-cover_letter_22" id="upload_btn_cover_letter_22" type="button"> add file</button>
# transcript
# -----------------------------------
# Data Privacy Statement
#  *
#
# <a href="#apply-dps-full-text" id="apply-dps-full-text-link" role="button"> By selecting ”I agree” you confirm that you have read, understand and consent to the Data Privacy Statement (click to read the whole statement).</a>
# privacy
# -----------------------------------
# Apply for this Job
#  *
#  Required
#  First Name
#  *
#
# <input aria-required="true" autocomplete="given-name" id="first_name" maxlength="255" name="job_application[first_name]" type="text"/>
# job title
# -----------------------------------
# Phone
#  *
#
# <input aria-required="true" autocomplete="tel" id="phone" maxlength="255" name="job_application[phone]" required="required" type="text"/>
# phone number
# -----------------------------------
# Link to your LinkedIn Profile
#
# <input aria-required="false" autocomplete="custom-question-link-to-your-linkedin-profile" id="job_application_answers_attributes_0_text_value" maxlength="255" name="job_application[answers_attributes][0][text_value]" type="text"/>
# linkedin
# -----------------------------------
# Gender *
#
# <select data-target="#gender" name="gender" placeholder="Please select …" required=""><option selected="selected" value=""> Please select …</option><option value="male"> Male</option><option value="female"> Female</option><option value="diverse"> Diverse</option><option value="undefined"> Undefined</option></select>
# sex
# -----------------------------------
# Visa requirements *
#
# <select data-target="#custom_attribute_1190970" name="custom_attribute_1190970" placeholder="Please select …" required=""><option selected="selected" value=""> Please select …</option><option value="custom_option_12751"> Yes, I need a visa</option><option value="custom_option_12752"> No, I do not need a visa</option></select>
# visa
# -----------------------------------
# Ihr Profil
#  Wählen Sie eine Option, um Ihren Lebenslauf hochzuladen
#  *
#
# <input id="idd" name="cvBorder:cvBorder_body:cv:upload:oneRowPanel:cvParser:form:cvFileInput" type="file"/>
# cv
# -----------------------------------
# Wir haben festgestellt, dass Sie bereits ein Konto bei uns besitzen. Bitte loggen Sie sich ein, um Ihre Bewerbung abzuschließen.
#  Telefon
#
# <input data-slnm="applicationform-input_phoneBorder" id="id9" name="phoneBorder:phoneBorder_body:phone" type="text" value=""/>
# phone number
# -----------------------------------
# Ja, ich möchte mit den Daten meiner Bewerbung einen softgarden Bewerberaccount anlegen. Die
#
# <a href="https://network.softgarden.io/#/privacy-policy/de/" target="_blank">softgarden Datenschutzhinweise </a>
# subscribe
# -----------------------------------
# habe ich zur Kenntnis genommen.
#
# <input data-slnm="applicationform-input_acceptPrivacyPolicy" id="id15" name="acceptPrivacyPolicyBorder:labelContainer:acceptPrivacyPolicyBorder_body:acceptPrivacyPolicy" type="checkbox"/>
# submit
# -----------------------------------
# LinkedIn Profile
#
# <input aria-required="false" autocomplete="custom-question-linkedin-profile" id="job_application_answers_attributes_0_text_value" maxlength="255" name="job_application[answers_attributes][0][text_value]" type="text"/>
# linkedin
# -----------------------------------
# Land/Region
#
# <select id="optionsFacetsDD_country" name="optionsFacetsDD_country"><option value=""> Alle</option></select>
# country
# -----------------------------------
# Nachname*
#  Bitte Nachname angeben
#
# <input id="email" maxlength="80" name="Email" placeholder="E-Mail*" required="" type="email"/>
# email
# -----------------------------------
# E-Mail*
#  Bitte E-Mail-Adresse angeben
#
# <input id="phone" kameleoonlistener-m6gb="true" maxlength="30" name="Phone" placeholder="Telefonnummer" type="text"/>
# email
# -----------------------------------
# *
#  Bitte stimmen Sie unseren Datenschutzbestimmungen zu.
#
# <button disabled="disabled" id="quick_job_application_submit" kameleoonlistener-8dtk="true" kameleoonlistener-ez0r="true" type="submit"> Bewerbung absenden</button>
# privacy
# -----------------------------------
# Dieses Formular ist durch Friendly Captcha geschützt. Für die Nutzung gilt die
#
# <a href="https://friendlycaptcha.com/de/legal/privacy-end-users/" rel="noopener noreferrer" target="_blank">Datenschutzerklärung </a>
# privacy
# -----------------------------------
# Search by Job Number, Title or Keyword
#
# <input aria-autocomplete="list" aria-controls="typehead-listbox" aria-haspopup="listbox" aria-owns="typehead-listbox" au-target-id="151" autocomplete="off" data-ph-at-id="globalsearch-input" data-ph-id="ph-default-1534424582390-26554095245798127-41827256106651432-5642774880976432-ph-global-search-v3ZtxcUt-nPVRfi" id="typehead" ignoreexpanded="true" name="typehead" ph-a11y-autocomplete="" phae="ph-global-search-v3" phae-ally="aria-controls#,aria-owns#" phae-bind-literal="globalsearchPlaceholder, placeholder" placeholder="Search by Job Number, Title or Keyword" type="text" value.bind="searchValue"/>
# search
# -----------------------------------
# Telefon
#
# <input autocomplete="tel" id="phone" maxlength="255" name="job_application[phone]" type="text"/>
# phone number
# -----------------------------------
# Point of Data Transfer / Datenschutzerklärung
#  *
#  English:
#  I agree that my personal data may be processed for the purposes of applying to a Viessmann Generations Group company in accordance with the
#
# <a href="https://www.viessmann.family/en/data-protection.html" target="_blank">Privacy Policy "Regulations for Applicants" </a>
# privacy
# -----------------------------------
# I accept / Ich stimme zu
#  Demographic Question / Demografische Frage EN/DE
#  EN: Different perspectives create the best solutions. At Viessmann we understand diversity as not only a social responsibility but also as one of the most important factors in driving Viessmann’s spirit of innovation and building the best solutions for all our customers. Tracking demographic data helps us to measure our recruiting efforts to fulfill that goal. All data collected here will be anonymised and not tied to individual profiles. Sharing this data with us is voluntary for you.
#  DE: Unterschiedliche Perspektiven schaffen die besten Lösungen. Bei Viessmann verstehen wir Vielfalt nicht nur als unsere soziale Verantwortung, sondern als einer der entscheidende Faktoren um Innovationen zu treiben und die besten Produkte für unsere Kunden zu entwickeln. Die Erfassung demografischer Daten hilft uns dabei, unsere Recruiting Aktivitäten zu messen, um dieses Ziel zu erreichen. Demografische Daten werden anonymisiert erfasst und stehen nicht in Verbindung mit individuellen Profilen. Die Weitergabe dieser Daten an uns ist für dich freiwillig.
#  Gender/Geschlecht
#  (Select one)
#
# <input name="job_application[demographic_answers][][answer_options][][answer_option_id]" type="checkbox" value="4002001003"/>
# ethnicity
# -----------------------------------
# Job Categories
#
# <button aria-label="Search" au-target-id="234" click.delegate="handleSubmitClick()" data-ph-at-id="globalsearch-button" data-ph-id="ph-default-1534424582390-26554095245798127-41827256106651432-5642774880976432-ph-global-search-v3ZtxcUt-ScUBBu" id="ph-search-backdrop" phae="ph-global-search-v3" phae-ally="aria-disabled#false" phae-bind-literal="globalsearchButtonAriaLabelText, aria-label" phae-main="1" phae-type="click" role="button" submit.delegate="handleSubmitClick()" type="submit">Search Jobs </button>
# search
# -----------------------------------
# Please review
#
# <a href="https://careers.bcg.com/bcg-recruitment-privacy-policy" target="_blank">BCG's recruiting privacy policy </a>
# search
# -----------------------------------
# and acknowledge that you have read our
#
# <a href="https://privacy.thewaltdisneycompany.com/en/current-privacy-policy/" target="_blank"></a>
# privacy
# -----------------------------------
# Resume/CV
#
# <button aria-describedby="accepted-filetypes resume-description resume-error" aria-label="Attach resume&amp;#x2F;cv." data-error="false" type="button"> Attach</button>
# transcript
# -----------------------------------
# Attach
#
# <input accept=".pdf,.doc,.docx,.txt,.rtf" id="resume" type="file"/>
# transcript
# -----------------------------------
# ,
#  or
#
# <button aria-describedby="resume-description resume-error" aria-label="Enter resume&amp;#x2F;cv manually." data-testid="resume-text" type="button"> enter manually</button>
# pronoun
# -----------------------------------
# enter manually
#  Accepted file types: pdf, doc, docx, txt, rtf
#  Cover Letter
#
# <button aria-describedby="accepted-filetypes cover_letter-description cover_letter-error" aria-label="Attach cover letter." data-error="false" type="button"> Attach</button>
# transcript
# -----------------------------------
# enter manually
#  Accepted file types: pdf, doc, docx, txt, rtf
#  Linkedin/Xing profile
#
# <input aria-describedby="question_5792994101-description question_5792994101-error question_5792994101-help" aria-errormessage="question_5792994101-error" aria-invalid="false" aria-label="Linkedin/Xing profile" aria-required="false" id="question_5792994101" maxlength="255" type="text" value=""/>
# transcript
# -----------------------------------
# charles has my consent to collect, store, and process my data for the purpose of considering me for employment, and for up to 182 days thereafter.
#  *
#
# <button aria-disabled="false" type="submit"> Submit application</button>
# privacy
# -----------------------------------
# Phone number
#  *
#
# <input aria-invalid="false" aria-required="true" id="personio_phone" name="personio[phone]" placeholder="Enter your phone number" type="phone"/>
# phone number
# -----------------------------------
# (Up to 3 URLs possible)
#  * Required fields
#  I have taken note of the
#
# <a data-gtm="careerApplicationForm__privacyLink--id140321" data-pendo="careerApplicationForm__privacyLink--id140321" href="/imprint/#privacy" rel="noopener" target="_blank"> privacy policy</a>
# search
# -----------------------------------
# I consent to my data being stored for 12 months for the purpose of further consideration and to                    being contacted for potential other suitable job offers. I can revoke this consent at any time.                        *
#
# <button data-gtm="careerApplicationForm__submitButton--id140321" data-pendo="careerApplicationForm__submitButton--id140321" id="personio_submit" name="personio[submit]" type="submit"> Submit your application</button>
# privacy
# -----------------------------------
# Progress of your application
#  1
#  Contact and information
#  2
#  Document upload
#  3
#  Privacy policy
#
# <button data-gtm="careerApplicationForm__submitButtonProgressBox--id140321" data-pendo="careerApplicationForm__submitButtonProgressBox--id140321" id="personio_submitProgressBox" name="personio[submit]ProgressBox" type="submit"> Submit your application</button>
# privacy
# -----------------------------------
# Search for jobs by title or keyword
#
# <input aria-haspopup="listbox" aria-labelledby="search_typeahead-label" autocomplete="off" dir="auto" id="search_typeahead" name="base_query" placeholder="Search for jobs by title or keyword" role="combobox" spellcheck="false" type="text" value=""/>
# search
# -----------------------------------
# GitHub (if available)
#
# <input name="custom_attribute_482330" placeholder="" type="text"/>
# github
# -----------------------------------
# An email is required
#  An email is required
#  Phone Number
#  *
#
# <input name="cPhoneNumber" ng-model="candidate.phone_number" placeholder="Phone Number" required="" type="text"/>
# email
# -----------------------------------
# Address is required
#  Cover Letter
#
# <textarea name="cCoverLetter" ng-model="candidate.cover_letter" placeholder=""></textarea>
# address
# -----------------------------------
# Loading...
#  Country
#
# <select id="optionsFacetsDD_country" name="optionsFacetsDD_country"><option value=""> All</option><option value="AR"> Argentina</option><option value="BE"> Belgium</option><option value="BR"> Brazil</option><option value="CL"> Chile</option><option value="FR"> France</option><option value="DE"> Germany</option><option value="IT"> Italy</option><option value="NL"> Netherlands</option><option value="PL"> Poland</option><option value="RO"> Romania</option><option value="RU"> Russia</option><option value="SK"> Slovakia</option><option value="ES"> Spain</option><option value="TR"> Türkiye</option><option value="UA"> Ukraine</option><option value="GB"> United Kingdom</option><option value="US"> United States</option></select>
# country
# -----------------------------------
# Onsite/ Remote
#
# <select id="optionsFacetsDD_customfield4" name="optionsFacetsDD_customfield4"><option value=""> All</option><option value="Hybrid Working Within Country"> Hybrid Working Within Country</option><option value="Onsite"> Onsite</option><option value="Remote"> Remote</option></select>
# linkedin
# -----------------------------------
# land
#
# <select data-country-type="1" id="9917" name="9917" tabindex="0"><option value="">land auswählen</option><option value="1">afghanistan</option><option value="3">albanien</option><option value="4">algerien</option><option value="5">amerikanisch-samoa</option><option value="241">amerikanische jungferninseln</option><option value="6">andorra</option><option value="7">angola</option><option value="8">anguilla</option><option value="9">antarktis</option><option value="10">antigua und barbuda</option><option value="11">argentinien</option><option value="12">armenien</option><option value="13">aruba</option><option value="16">aserbaidschan</option><option value="14">australien</option><option value="17">bahamas</option><option value="18">bahrain</option><option value="19">bangladesch</option><option value="20">barbados</option><option value="21">belarus</option><option value="22">belgien</option><option value="23">belize</option><option value="24">benin</option><option value="25">bermuda</option><option value="26">bhutan</option><option value="27">bolivien (plurinationaler staat)</option><option value="247">bonaire, sint eustatius und saba</option><option value="28">bosnien und herzegowina</option><option value="29">botswana</option><option value="30">bouvetinsel</option><option value="31">brasilien</option><option value="240">britische jungferninseln</option><option value="32">britisches territorium im indischen ozean</option><option value="33">brunei</option><option value="34">bulgarien</option><option value="35">burkina faso</option><option value="36">burundi</option><option value="44">chile</option><option value="45">china</option><option value="52">cookinseln</option><option value="53">costa rica</option><option value="249">curaçao</option><option value="51">demokratische republik kongo</option><option value="116">demokratische volksrepublik korea</option><option value="81">deutschland</option><option value="61">dominica</option><option value="62">dominikanische republik</option><option value="60">dschibuti</option><option value="59">dänemark</option><option value="63">ecuador</option><option value="65">el salvador</option>&lt;option class="wizardfieldinput" value</select>
# country
# -----------------------------------
# e-mail adresse
#  *
#
# <input autocomplete="email" data-testid="textinput" id="email" name="email" required="" type="email" value=""/>
# email
# -----------------------------------
# gelesen habe.
#
# <button type="submit">jetzt bewerben</button>
# transcript
# -----------------------------------
# e-mail
#
# <input name="email" placeholder="erika.mustermann@email.de" type="email" value=""/>
# email
# -----------------------------------
# handy
#  (optional)
#
# <input name="phone" placeholder="+49 123 2222 2222" value=""/>
# search
# -----------------------------------
# name *
#
# <input name="first_name" placeholder="first" required="" type="text"/>
# first name
# -----------------------------------
# this field contains invalid characters
#
# <input name="last_name" placeholder="last" required="" type="text"/>
# pronoun
# -----------------------------------
# gender *
#
# <select data-target="#gender" name="gender" placeholder="please select …" required=""><option selected="selected" value="">please select …</option><option value="male">male</option><option value="female">female</option><option value="diverse">diverse</option><option value="undefined">undefined</option></select>
# sex
# -----------------------------------
# i hereby confirm that i have read and understood the
#
# <a data-locale="en" href="javascript:void();">data privacy statement</a>
# website language
# -----------------------------------
# .
#  *
#  uploading document. please wait.
#
# <button disabled="" type="submit">send application</button>
# transcript
# -----------------------------------
# telefonnummer
#  *
#
# <button aria-expanded="false" aria-haspopup="listbox" aria-label="ländervorwahl auswählen" aria-live="polite" id="country-select-input-candidate.phone-5" type="button">deutschlanddeutschland</button>
# phone number
# -----------------------------------
# international
#  afghanistan
#  afghanistan
#
# <input aria-describedby="input-candidate.phone-5-error" aria-invalid="false" autocomplete="tel" id="input-candidate.phone-5" name="candidate.phone" placeholder="telefonnummer" required="" type="tel" value="+49"/>
# country
# -----------------------------------
# alle mit
#  *
#  markierten felder sind pflichtfelder.
#
# <button aria-busy="false" aria-live="polite" type="submit">senden</button>
# submit
# -----------------------------------
# nachname*
#  bitte nachname angeben
#
# <input id="email" maxlength="80" name="email" placeholder="e-mail*" required="" type="email"/>
# first name
# -----------------------------------
# e-mail*
#  bitte e-mail-adresse angeben
#
# <input id="phone" kameleoonlistener-1ld2="true" maxlength="30" name="phone" placeholder="telefonnummer" type="text"/>
# email
# -----------------------------------
# *
#  bitte stimmen sie unseren datenschutzbestimmungen zu.
#
# <button disabled="disabled" id="quick_job_application_submit" kameleoonlistener-dwnw="true" kameleoonlistener-sxpm="true" type="submit">bewerbung absenden</button>
# privacy
# -----------------------------------
# dieses formular ist durch friendly captcha geschützt. für die nutzung gilt die
#
# <a href="https://friendlycaptcha.com/de/legal/privacy-end-users/" rel="noopener noreferrer" target="_blank">datenschutzerklärung</a>
# privacy
# -----------------------------------
# land/region
#
# <select id="optionsfacetsdd_country" name="optionsfacetsdd_country"><option value="">alle</option></select>
# country
# -----------------------------------
# by registering on the nato e-recruitment website:
#  i agree to the processing of my personal data as described in the privacy statement that appears below;
#  i agree that i will only create one nato account and i confirm that i do not already have one. i am aware that if i do not abide by this rule it will lead to my being excluded from the competitions/selection procedures that i applied for via those accounts;
#  i accept that nato may inform the delegation of the country to which i am a national about my application, should i be long- or shortlisted for a post;
#  i understand that the information provided in my application will be used in determining my qualifications for possible employment with nato. the statements made by me in the foregoing responses are true, complete and correct to the best of my knowledge and belief. i understand i will be requested to supply documentary evidence in support of the statements i make in this application. i understand that any misrepresentation or material omission made on an application for employment or other document requested by the organization may lead to my rejection in the selection process or to termination or dismissal.
#  -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  privacy statement
#  this privacy statement is associated with nato’s externally-provided online recruitment system. the privacy statement will provide you general guidance on the processing of personal data by nato only for recruitment-related purposes.
#  please read this privacy statement carefully prior to providing your personal data into the nato online recruitment system. if you do not agree with this privacy statement, you should not provide your personal data into the system.
#  coverage of personal data
#  this privacy statement covers any personal data that you submit through nato’s online recruitment system including, but not limited to:
#  name, addresses, telephone numbers, email addresses, other contact information;
#  log-in and password and other such information used in connection with authenticating you;
#  cv, letter of motivation, previous work experience, education level, competences and skills, and how you heard about the position.
#  your data protection and data security
#  by submitting and saving your personal details in nato’s online recruitment system, you agree on providing your explicit consent to nato to control, save, transfer and process your personal data on a need-to-know basis as outlined in this privacy statement.
#  collection and use of personal data
#  nato collects your personal data for specified, explicit and legitimate purposes and will not further process your personal data in a way incompatible with those purposes. specifically, nato collects your personal data for the purposes of managing its resourcing and recruitment activities, as well as for interview planning purposes. consequently, nato may use your personal data in relation to the evaluation and selection of your application, including, but not limited to, setting up and conducting interviews and tests, evaluating and assessing the results thereto and as is otherwise needed in recruitment processes, including the final recruitment. nato may collect personal data directly from candidates as well as from information sources that are publicly available, such as social media or other publicly available websites.
#  data retention
#  nato will retain your personal data for 5 years from the date of submission or the latest update of your details /account information. after 5 years from the submission or the latest update of your data, your personal data will be deleted and will not be accessible for viewing or tracking.
#  if you are successful in the nato recruitment process and become an employee, your personal data may become a part of your personnel file, may be used for other employment/work-related purposes and may be kept in nato’s talent pool for possible future roles. your personal data may also be subject to further additional privacy terms related to nato employees.
#  information security
#  your personal data will be treated with utmost confidentiality on a need-to-know basis only. in certain specific circumstances, nato will need to transmit your personal data, or information based on your personal data, to third parties (such as, but not limited to, selection providers or test administrators) on a need-to-know basis and for the performance of its recruitment and selection functions only. appropriate measures are taken to protect the integrity of such data during transfer. nato may also take appropriate back-up copies and use other such means to prevent the accidental damage or destruction to your personal data and to ensure that our services are functioning properly.
#  nato international civilians
#  please note that in selecting members of the staff to fill vacant posts, account will be taken of their professional qualifications, performance record and experience.
#
# <input id="dialogtemplate-dialogform-statementbeforeauthentificationcontent-continuebutton" name="dialogtemplate-dialogform-statementbeforeauthentificationcontent-continuebutton" onclick="if (!event) {event = window.event;}cmdsubmit('dialogtemplate-dialogform','dialogtemplate-dialogform-statementbeforeauthentificationcontent-continuebutton',null, null, true);return taleo.core.event.setandreturnfalse(event);" title="i accept" type="button" value="i accept"/>
# privacy
# -----------------------------------
# and confirm that i've reviewed the
#
# <a data-testid="link" href="https://join.com/privacy-policy" rel="noopener" target="_blank">privacy policy</a>
# search
# -----------------------------------
# please refer to our
#
# <a href="https://www.think-cell.com/en/privacy" target="_blank">privacy policy</a>
# find us
# -----------------------------------
# lebenslauf
#  *
#  lebenslauf hochladen
#
# <input accept="application/msword, application/vnd.openxmlformats-officedocument.wordprocessingml.document, application/pdf, application/vnd.oasis.opendocument.text, application/rtf, text/plain, image/png, image/jpeg" aria-describedby="input-candidate.cv-5-error input-candidate.cv-6" aria-hidden="true" aria-invalid="false" aria-labelledby="input-candidate.cv-7" autocomplete="off" data-cy="fileinputfield" id="input-candidate.cv-5" name="candidate.cv" required="" tabindex="-1" type="file"/>
# transcript
# -----------------------------------
# search jobs
#  keyword
#
# <input autocomplete="off" id="search-keyword-32b8e8006f" maxlength="150" name="k" placeholder="search job title, category, or keyword(s)" type="search" value=""/>
# search
# -----------------------------------
# location
#
# <input aria-describedby="search-error-1" aria-invalid="false" autocomplete="off" data-ajax-url="/en/search-jobs/locations?term=" data-country-codes="" data-display-typeahead="true" data-error-message="please try again. choose a location from the suggestions or clear the field to submit your search." data-kt="" data-lat="" data-lon="" data-lp="" data-lt="" id="search-location-32b8e8006f" maxlength="150" name="l" placeholder="city, state, or zip" type="text" value=""/>
# city
# -----------------------------------
# dieses feld enthält ungültige zeichen.
#
# <input name="last_name" placeholder="nachname" required="" type="text"/>
# cover letter
# -----------------------------------
# zur kenntnis genommen habe.
#  *
#  dokument wird hochgeladen. bitte warten sie.
#
# <button disabled="" type="submit">bewerbung abschicken</button>
# transcript
# -----------------------------------
# cv or resume
#  *
#  upload your cv or resume file
#
# <input accept="application/msword, application/vnd.openxmlformats-officedocument.wordprocessingml.document, application/pdf, application/vnd.oasis.opendocument.text, application/rtf, text/plain, image/png, image/jpeg" aria-describedby="input-candidate.cv-3-error input-candidate.cv-4" aria-hidden="true" aria-invalid="false" aria-labelledby="input-candidate.cv-5" autocomplete="off" data-cy="fileinputfield" id="input-candidate.cv-3" name="candidate.cv" required="" tabindex="-1" type="file"/>
# cv
# -----------------------------------
# cover letter
#  upload your cover letter
#
# <input accept="application/msword, application/vnd.openxmlformats-officedocument.wordprocessingml.document, application/pdf, application/vnd.oasis.opendocument.text, application/rtf, text/plain, image/png, image/jpeg" aria-describedby="input-candidate.coverletterfile-8-error input-candidate.coverletterfile-9" aria-hidden="true" aria-invalid="false" aria-labelledby="input-candidate.coverletterfile-10" autocomplete="off" data-cy="candidate.coverletterfile" id="input-candidate.coverletterfile-8" name="candidate.coverletterfile" tabindex="-1" type="file"/>
# cover letter
# -----------------------------------
# github
#
# <input name="custom_attribute_356304" placeholder="" type="text"/>
# github
# -----------------------------------
# ihre e-mail-adresse
#
# <button aria-label="subscribe for newsletter" type="submit"></button>
# email
# -----------------------------------
# (!)
#  this field is required
#
# <button id="uploaddropboxresume" type="submit" value="continue">continue</button>
# find us
# -----------------------------------
# this field is required
#  from device
#  *
#
# <input accept=".pdf,.doc,.docx,.txt" aria-required="true" id="resumefile" name="resumefile" type="file"/>
# privacy
# -----------------------------------
